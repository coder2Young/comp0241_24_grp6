# %% [markdown]
# # Lab3: Homography, RANSAC, and Fundemental Matrix
#
# We have gone through filtering, feature detection and description last week. For this week, we are gonna make attampts on using the extracted features to align images from planar scene for generating panaroma, triangulate world points in 3D, and estimating camera pose.
#
#
# ### At the moment this jupyter notebook only contain the first half of the lab sessions and the other half will be released before the next lab session.

# %% [markdown]
# ## Part 1: Image Transformation
#
# ## Task 1: Image Transformations
# Your first task is rather simple and just requires you to run an example.
# The idea is just to show you a beneficial use of applying affine or perspective transformations to images and how this could be used in practice.
#
# First load and show the images:

# %%
import numpy as np
import copy
import cv2
import matplotlib
from matplotlib import pyplot as plt
import random
import copy
from PIL import Image
#to visualize the plots within the notebook
# %matplotlib inline
# for making plots looking nicer
plt.style.use('fivethirtyeight')

# %%
# Load images
tag_img = cv2.imread('../dataset/plate_side.jpg')
tag_img = cv2.cvtColor(tag_img, cv2.COLOR_BGR2GRAY)

ref_img = cv2.imread('../dataset/reference.jpg')
ref_img = cv2.cvtColor(ref_img, cv2.COLOR_BGR2GRAY)


plt.figure()
plt.title("reference image")
plt.imshow(ref_img, 'gray')
# JINGWEN: I can't run this...
# Locate points of the documents or object which you want to transform into
# ref_pts = plt.ginput(4)
plt.show()

# Locate points of the documents or object which you want to transform
plt.figure()
plt.title("shot in real world")
plt.imshow(tag_img, 'gray')
# tag_pts = plt.ginput(4)
plt.show()

# %% [markdown]
# The goal is to compute the 2D affine transformation that maps points from the source frame to the reference frame. The affine transformation consists of a linear transformation (rotation, scaling, and shearing) and a translation, requiring six degrees of freedom (6-DoF). We need at least 3 correspondences to solve this. We can get least squre solution if more than 3 pair of correspondences are given.
#
# $$
# \begin{bmatrix}x \\ y\end{bmatrix} = \begin{bmatrix}a_{11} & a_{12} \\ a_{21} & a_{22}\end{bmatrix} \begin{bmatrix}x^{\prime} \\ y^{\prime}\end{bmatrix} + \begin{bmatrix}t_1 \\ t_2\end{bmatrix}
# $$

# %%
# We could use the following 4 points:
ref_pts = np.array([[11.8, 11.0],
                    [270.9, 13.1],
                    [270.9, 67.9],
                    [14.9, 67.4]])  # [4, 3]: top-left, top-right, bottom-right, bottom-left

tag_pts = np.array([[95.6, 84.0],
                    [211.6, 101.3],
                    [211.1, 141.3],
                    [97.6, 112.2]])

Y = ref_pts.transpose(1, 0)  # [2, N]
X = tag_pts.transpose(1, 0)  # [2, N]
X = np.concatenate([X, np.ones((1, 4))], axis=0)  # [3, N]

# %% [markdown]
# ## Task1.1: Call OpenCV function as reference result

# %%
# switch to inline plot and we can see plots in the notebook
# %matplotlib inline

# Apply Perspective Transform Algorithm
matrix = cv2.getPerspectiveTransform(np.float32(tag_pts), np.float32(ref_pts))
result = cv2.warpPerspective(tag_img, matrix, (280, 80))
# Wrap the transformed image

# Plot Input, Output and Matched image
plt.figure(figsize=(15,10))

plt.subplot(231)
plt.imshow(tag_img, 'gray')
plt.grid(False)
plt.title('Inital Image')

plt.subplot(232)
plt.imshow(result, 'gray')
plt.grid(False)
plt.title('Transformed Image')
plt.show()

print("Solved transform matrix:")
print(matrix, "\n")
Y_ = matrix @ X
print("Transformed points before de-homogenising:")
print(Y_, "\n")
Y_ /= Y_[2, :]
print("Transformed points after de-homogenising:")
print(Y_)
# Out:
# Solved transform matrix:
# [[ 5.33962992e+00 -2.13089797e-01 -4.74046561e+02]
#  [-3.51693314e-01  3.13291883e+00 -2.12276557e+02]
#  [ 6.79228821e-03 -9.48079999e-04  1.00000000e+00]]
#
# Transformed points before de-homogenising:
# [[ 18.52251562 634.23313251 623.03972566  23.19264316]
#  [ 17.26674366  30.66981496 156.16241466 104.91166793]
#  [  1.56970403   2.34120768   2.29988834   1.55655275]]
#
# Transformed points after de-homogenising:
# [[ 11.80000511 270.89998786 270.89998915  14.90000459]
#  [ 10.99999955  13.09999758  67.8999985   67.40000793]
#  [  1.           1.           1.           1.        ]]

# %% [markdown]
# ## Task1.2: Solve affine matrix using least square.
#
# Next, we solve the $2\times3$ affine matrix with our own solver based on standard-form least-square:
#
# $$
# \begin{bmatrix}x \\ y\end{bmatrix} = \begin{bmatrix}a_{11} & a_{12} & t_1 \\ a_{21} & a_{22} & t_2\end{bmatrix} \begin{bmatrix}x^{\prime} \\ y^{\prime} \\ 1\end{bmatrix}
# $$
#
# $$
# \mathbf{y} = \mathbf{A} \mathbf{x}, \quad \text{where} \quad \mathbf{x} \in \mathbb{R}^{D_1}, \mathbf{y} \in \mathbb{R}^{D_2}
# $$
#
# Suppose we have $N$ correspondences. We can stack the vectors:
#
# $$
# \mathbf{Y} = \mathbf{A} \mathbf{X}, \quad \text{where} \quad \mathbf{X} \in \mathbb{R}^{D_1 \times N}, \mathbf{A} \in \mathbb{R}^{D_2 \times D_1}, \mathbf{X} \in \mathbb{R}^{D_2 \times N}
# $$
#
# $\mathbf{A}$ could be solved by standard least-square:
#
# $$
# \mathbf{A} = \mathbf{Y} \mathbf{X}^T(\mathbf{X} \mathbf{X}^T)^{-1}
# $$

# %%
#TODO Work out the affine matrix M from X and Y here:
def get_affine_matrix(X, Y):
    A = Y @ X.T @ np.linalg.inv(X @ X.T)

    return A

# %%
A = get_affine_matrix(X, Y)
# Transform the affine matrix M to a transformation matrix M
M = np.zeros((3, 3))
M[2, 2] = 1
M[:2, :] = A

warped_2 = cv2.warpPerspective(tag_img, M, (280, 80))
plt.figure(figsize=(15,10))

plt.subplot(231)
plt.imshow(tag_img, 'gray')
plt.grid(False)
plt.title('Inital Image')

plt.subplot(232)
plt.imshow(warped_2, 'gray')
plt.grid(False)
plt.title('Transformed Image')
plt.show()

print("Solved transform matrix:")
print(M, "\n")
Y_ = M @ X
print("Transformed points before de-homogenising:")
print(Y_, "\n")
Y_ /= Y_[2, :]
print("Transformed points after de-homogenising:")
print(Y_)
# Out:
# Solved transform matrix:
# [[ 2.24377037e+00  2.68909214e-03 -2.03654537e+02]
#  [-3.07284650e-01  1.58137510e+00 -8.63126941e+01]
#  [ 0.00000000e+00  0.00000000e+00  1.00000000e+00]]
#
# Transformed points before de-homogenising:
# [[ 11.07579471 271.39967947 270.38535797  15.63916785]
#  [ 17.14640144   8.85917126  72.26781744  61.12660986]
#  [  1.           1.           1.           1.        ]]
#
# Transformed points after de-homogenising:
# [[ 11.07579471 271.39967947 270.38535797  15.63916785]
#  [ 17.14640144   8.85917126  72.26781744  61.12660986]
#  [  1.           1.           1.           1.        ]]

# %% [markdown]
# ## Task1.3: Solve homography with DLT.
# Finally, we solve the homography matrix (8-DoF) via DLT. DLT is to rewrite similarity equations $\mathbf{y} = \alpha\mathbf{A}\mathbf{x}$ as homogenous linear equation and solve.
#
# $$
# \begin{align}
#     \begin{bmatrix}x \\ y \\ 1\end{bmatrix} = \alpha\begin{bmatrix}h_{11} & h_{12} & h_{13} \\ h_{21} & h_{22} & h_{23} \\ h_{31} & h_{32} & h_{33} \end{bmatrix}\begin{bmatrix}x^{\prime} \\ y^{\prime} \\ 1\end{bmatrix}
# \end{align}
# $$
#
# Here we have two more DoFs and the solution is up to an unknown scale factor $\alpha$. More introduction about similarity equations and DLT can be found at: https://en.wikipedia.org/wiki/Direct_linear_transformation
#
# Expand the above equation and we get:
#
# $$
# \begin{align}
#     x = \alpha (h_{11} x^{\prime} + h_{12} y^{\prime} + h_{13}) \\
#     y = \alpha (h_{21} x^{\prime} + h_{22} y^{\prime} + h_{23}) \\
#     1 = \alpha (h_{31} x^{\prime} + h_{32} y^{\prime} + h_{33}) \\
# \end{align}
# $$
#
# Eliminate $\alpha$, we get:
#
# $$
# \begin{align}
#     (h_{31} x^{\prime} + h_{32} y^{\prime} + h_{33}) x = (h_{11} x^{\prime} + h_{12} y^{\prime} + h_{13}) \\
#     (h_{31} x^{\prime} + h_{32} y^{\prime} + h_{33}) y = (h_{21} x^{\prime} + h_{22} y^{\prime} + h_{23}) \\
# \end{align}
# $$
#
# $$
# \begin{align}
#     h_{31} xx^{\prime} + h_{32} xy^{\prime} + h_{33}x - h_{11} x^{\prime} - h_{12} y^{\prime} - h_{13}) = 0 \\
#     h_{31} yx^{\prime} + h_{32} yy^{\prime} + h_{33}y - (h_{21} x^{\prime} - h_{22} y^{\prime} - h_{23}) = 0 \\
# \end{align}
# $$
#
# In matrix form:
#
# $$
# \mathbf{A}_i\mathbf{h} = \mathbf{0}
# $$
#
# $$
# \mathbf{A}_i = \begin{bmatrix}-x^{\prime} & -y^{\prime} & -1 & 0 & 0 & 0 & xx^{\prime} & xy^{\prime} & x \\
# 0 & 0 & 0 & -x^{\prime} & -y^{\prime} & -1 & yx^{\prime} & yy^{\prime} & y
# \end{bmatrix}
# $$
#
# $$
# \mathbf{h} = \begin{bmatrix}h_{11} & h_{12} & h_{13} & h_{21} & h_{22} & h_{23} & h_{31} & h_{32} & h_{33}\end{bmatrix}^T
# $$
#
# This is a total least squares minimization problem which can be solved via SVD:
#
# $$
# \mathbf{A} = \mathbf{U}\mathbf{\Sigma}\mathbf{V}^T
# $$
#
# Choosing the last column of $\mathbf{V}$ to be $\mathbf{h}$
#
# https://en.wikipedia.org/wiki/Singular_value_decomposition

# %%
# Workout homography matrix here:

##TODO First construct Ai from one point pair:
def construct_a_from_pts(ref, tag):
    ##TODO populate matrices here
    x, y = ref
    u, v = tag
    Ai = np.array([[-u, -v, -1, 0, 0, 0, x*u, x*v, x],
                   [0, 0, 0, -u, -v, -1, y*u, y*v, y]])
    
    return Ai

##TODO Assmble A and solve it, 
n_pts = ref_pts.shape[0]
A = np.zeros((2 * n_pts, 9))
for i in range(n_pts):
    A[2*i:2*i+2, :] = construct_a_from_pts(ref_pts[i], tag_pts[i])
    
##TODO Find V and construct M, remember normalization!
_, _, Vh = np.linalg.svd(A)
H = Vh[-1, :].reshape(3, 3)
H /= H[2, 2]

# %%
# Transform the homography matrix H to a transformation matrix M
M2 = np.zeros((3, 3))
M2[2, 2] = 1
M2[:3, :] = H

warped_dlt = cv2.warpPerspective(tag_img, M2, (280, 80))
plt.figure(figsize=(15,10))

plt.subplot(231)
plt.imshow(tag_img, 'gray')
plt.grid(False)
plt.title('Inital Image')

plt.subplot(232)
plt.imshow(warped_dlt, 'gray')
plt.grid(False)
plt.title('Transformed Image')
plt.show()

print("Solved transform matrix:")
print(M2, "\n")
Y_ = M2 @ X
print("Transformed points before de-homogenising:")
print(Y_, "\n")
Y_ /= Y_[2, :]
print("Transformed points after de-homogenising:")
print(Y_)
# Out:
# Solved transform matrix:
# [[ 5.33962832e+00 -2.13089683e-01 -4.74046430e+02]
#  [-3.51693163e-01  3.13291769e+00 -2.12276479e+02]
#  [ 6.79228393e-03 -9.48079239e-04  1.00000000e+00]]
#
# Transformed points before de-homogenising:
# [[ 18.52250352 634.23293661 623.03953512  23.19263108]
#  [ 17.26674057  30.66980978 156.1623641  104.9116332 ]
#  [  1.56970369   2.34120685   2.29988754   1.55655242]]
#
# Transformed points after de-homogenising:
# [[ 11.8 270.9 270.9  14.9]
#  [ 11.   13.1  67.9  67.4]
#  [  1.    1.    1.    1. ]]

# %% [markdown]
# ## Part 2 Panaroma

# %% [markdown]
# ## Task2
# The aim of Task2 is to calculate the homography that best maps two sets of points to one another. We will (eventually) use this for creating panoramas, and for calculating the 3D pose of planes. You should use this
# template for your code and fill in the missing sections marked "TO DO."

# %% [markdown]
# ## Import libraries

# %%
# %matplotlib inline
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

# %% [markdown]
# ## Task 2.1 Test case formulation
#
# To start with, let's set up some start points `pts1Cart` and a homography, `H`, that we can use to generate target points `pts2Cart`. We'll also add some noise to `pts2Cart` to simulate a real world environment. The challenge is to find the same homography, or as close as noise allows, given `pts1Cart` and `pts2Cart`.
#
# __NOTE:__ It may be helpful to set `noiseLevel` to 0 to start with so that you can check if your solution is spot on while debugging. Make sure you set it back to some value, here we use 4, when you're confident your solution works.

# %%
# Define a set of two-dimensional Cartesian points
pts1Cart = np.array([[240.5000, 16.8351, 33.5890, 164.2696, 149.1911],
                    [248.8770, 193.5890, 251.3901, 168.4581, 228.7723]])

# Convert points into homogeneous representation
pts1Hom = np.concatenate((pts1Cart, np.ones((1,pts1Cart.shape[1]))), axis=0)

# Define a homography
H = np.array([[0.6, 0.7, -100.],
              [1.0, 0.6, 50.],
              [0.001, 0.002, 1.0]])

# Apply a homography to the points
pts2Hom = np.matmul(H,pts1Hom)

# Convert back to Cartesian coordinates
pts2Cart = pts2Hom[0:2,:] / np.tile([pts2Hom[2,:]],(2,1))

# Add a small amount of noise. Set this to zero to begin with to see if your homography solution is spot on.
noiseLevel = 4.0
pts2Cart = pts2Cart + np.random.normal(0, noiseLevel, pts2Cart.shape)

# %% [markdown]
# ## Plotting
#
# Let's plot the the first original set of points, `pts1Cart`, in blue and the second set of points, `pts2Cart`, in red.

# %%
# Plot a green line between pairs of start points (blue) and transformed points (red).
nPoint = pts1Cart.shape[1]
for cPoint in range(0, nPoint):
    plt.plot([pts1Cart[0,cPoint], pts2Cart[0,cPoint]], [pts1Cart[1,cPoint], pts2Cart[1,cPoint]],'g-')
    plt.plot(pts1Cart[0,cPoint],pts1Cart[1,cPoint],'b.', pts2Cart[0,cPoint],pts2Cart[1,cPoint],'r.') 

plt.show()

# %% [markdown]
# ## Task 2.2 Homography estimation time!
#
# We've formulated our test example; now our goal is to estimate the homography that maps the first set of points to the second set of points.
#
# ### ****TO DO****: Fill in the details of these routines (solveAXEqualsZero and calcBestHomography).

# %%
def solveAXEqualsZero(A):
    # TO DO: Write this routine - it should solve Ah = 0. You can do this using SVD. Check the task above.
    # Hint: SVD will be involved. 
    U, S, Vh = np.linalg.svd(A)
    h = Vh[-1, :]

    return h

# %%
def calcBestHomography(pts1Cart, pts2Cart):
    
    # This function should apply the direct linear transform (DLT) algorithm to calculate the best 
    # homography that maps the cartesian points in pts1Cart to their corresonding matching cartesian poitns 
    # in pts2Cart.
    
    # This function calls solveAXEqualsZero. Make sure you are wary of how to reshape h into a 3 by 3 matrix. 

    n_points = pts1Cart.shape[1]
    
    #TODO: replace this:
    H = np.identity(3)

    #TODO: 
    # First convert points into homogeneous representation
    # Hint: we've done this before  in the skeleton code we provide.

    # Then construct the matrix A, size (n_points * 2, 9) using construct_a_from_pts
    # Consult the notes!
    A = np.zeros((2 * n_points, 9))
    for i in range(n_points):
        A[2*i:2*i+2, :] = construct_a_from_pts(pts1Cart[:, i], pts2Cart[:, i])

    # Solve Ah = 0 using solveAXEqualsZero and get h.
    h = solveAXEqualsZero(A)

    # Reshape h into the matrix H, values of h go first into rows of H
    H = h.reshape(3, 3)
    H = H / H[2, 2]
    
    return H

# %% [markdown]
# ## Test time!
#
# Time to put it all together.
#
# Now we need a way of measuring how well our mapping does. To do this we will apply our estimated mapping, `HEst`, to `pts1Cart` and obtain estimated points `pts2EstCart`. We will compare `pts2EstCart` and `pts2Cart` using a sum of squared difference to see how well our solution at least approximates the transformed noisy points `pts2Cart`.
#
# Red points on the plot are the noisy points we observe, `pts2Cart`, and the magenta points are the transformed points, `pts2EstCart`, that we get when we apply our estimated homography on `pts1Cart`. The black lines represent the error between both points; if you've set `noiseLevel` to 0, then `sqDiff` should be 0 and the points should overlap perfectly.

# %%
# Replace this with a call to the function calcBestHomography. You'll need to figure out which way around the 
# points go in the function, i.e. which direction this homography transforms points from and to. The ordering 
# is dead simple for now but acts as a simple exercise for what comes in later parts of this practical.
HEst = calcBestHomography(pts2Cart, pts1Cart)

# Apply estimated homography to points
pts2EstHom = np.matmul(HEst,pts1Hom)

# Convert back to Cartesian coordinates
pts2EstCart = pts2EstHom[0:2,:] / np.tile([pts2EstHom[2,:]],(2,1))

# Calculate the mean squared distance from actual points
sqDiff = np.mean(sum((pts2Cart - pts2EstCart)**2))

print("Sqaured difference between pts2Cart and pts2EstCart is: %.2f" % sqDiff)

# Draw figure with points before and after applying the estimated homography
nPoint = pts1Cart.shape[1]

# Plot a black line between pairs of actual points (red) and estimated points (magenta)
for cPoint in range(0, nPoint):
    plt.plot([pts2Cart[0,cPoint], pts2EstCart[0,cPoint]], [pts2Cart[1,cPoint], pts2EstCart[1,cPoint]],'k-')
    plt.plot(pts2Cart[0,cPoint],pts2Cart[1,cPoint],'r.',pts2EstCart[0,cPoint],pts2EstCart[1,cPoint],'m.') 

plt.show()
# Out:
# Estimated homography:
# [[ 8.05320259e-01  8.50923864e-01 -1.34818885e+02]
#  [ 1.33171991e+00  6.98467239e-01  4.85407410e+01]
#  [ 1.93560950e-03  2.80159081e-03  1.00000000e+00]]
# Points estimated by the homography:
# [[125.13423318  27.59988903  59.99231846  78.67187445  93.27633558]
#  [250.90643679 130.91007633 151.95755863 215.07437373 210.91932249]]
# Sqaured difference between pts2Cart and pts2EstCart is: 0.37

# %% [markdown]
# ## Other things **** TO DO ****
#
# 1: Convince yourself that the homography is ambiguous up to scale (by
# multiplying it by a constant factor and showing it does the same thing).
# Can you see why this is the case mathematically?
#
# 2: Show empirically that your homography routine can EXACTLY map any four points to any
# other four points.

# %%
HEst = calcBestHomography(pts2Cart, pts1Cart)
k = 100
HEst_ktimes = HEst * k

print("Solved transform matrix:")
print(HEst, "\n")
print("Solved transform matrix after k times:")
print(HEst_ktimes, "\n")

# Apply estimated homography to points
pts2EstHom = np.matmul(HEst,pts1Hom)
pts2EstHom_ktimes = np.matmul(HEst_ktimes,pts1Hom)


# Convert back to Cartesian coordinates
pts2EstCart = pts2EstHom[0:2,:] / np.tile([pts2EstHom[2,:]],(2,1))
pts2EstCart_ktimes = pts2EstHom_ktimes[0:2,:] / np.tile([pts2EstHom_ktimes[2,:]],(2,1))

# Calculate the mean squared distance from actual points
sqDiff = np.mean(sum((pts2Cart - pts2EstCart)**2))
sqDiff_ktimes = np.mean(sum((pts2Cart - pts2EstCart_ktimes)**2))
                        

print("Sqaured difference between pts2Cart and pts2EstCart is: %.2f" % sqDiff)
print("Sqaured difference between pts2Cart and pts2EstCart_ktimes is: %.2f" % sqDiff_ktimes)

# Draw figure with points before and after applying the estimated homography
nPoint = pts1Cart.shape[1]

# Plot a black line between pairs of actual points (red) and estimated points (magenta)
for cPoint in range(0, nPoint):
    plt.plot([pts2Cart[0,cPoint], pts2EstCart[0,cPoint]], [pts2Cart[1,cPoint], pts2EstCart[1,cPoint]],'k-')
    plt.plot(pts2Cart[0,cPoint],pts2Cart[1,cPoint],'r.',pts2EstCart[0,cPoint],pts2EstCart[1,cPoint],'m.') 

    #Plot a green line between pairs of actual points (red) and estimated points after k times (blue)
    plt.plot([pts2Cart[0,cPoint], pts2EstCart_ktimes[0,cPoint]], [pts2Cart[1,cPoint], pts2EstCart_ktimes[1,cPoint]],'g-')
    plt.plot(pts2Cart[0,cPoint],pts2Cart[1,cPoint],'r.',pts2EstCart_ktimes[0,cPoint],pts2EstCart_ktimes[1,cPoint],'b.')

plt.show()
# Out:
# Solved transform matrix:
# [[ 8.05320259e-01  8.50923864e-01 -1.34818885e+02]
#  [ 1.33171991e+00  6.98467239e-01  4.85407410e+01]
#  [ 1.93560950e-03  2.80159081e-03  1.00000000e+00]]
#
# Solved transform matrix after k times:
# [[ 8.05320259e+01  8.50923864e+01 -1.34818885e+04]
#  [ 1.33171991e+02  6.98467239e+01  4.85407410e+03]
#  [ 1.93560950e-01  2.80159081e-01  1.00000000e+02]]
#
# Sqaured difference between pts2Cart and pts2EstCart is: 0.37
# Sqaured difference between pts2Cart and pts2EstCart_ktimes is: 0.37

# %%
# Randomly generate some source points and destination points
src_points = [(random.uniform(0, 100), random.uniform(0, 100)) for _ in range(4)]
dst_points = [(random.uniform(0, 100), random.uniform(0, 100)) for _ in range(4)]

H = calcBestHomography(np.array(dst_points).T, np.array(src_points).T)

src_points_homogeneous = [np.array([x, y, 1]) for x, y in src_points]
mapped_points = [H @ p for p in src_points_homogeneous]
mapped_points = [p / p[2] for p in mapped_points]

print("Source points:")
print(src_points)
print("Destination points:")
print(dst_points)
print("Mapped points:")
# Rearrange the mapped points to be in the same order as the destination points
mapped_points = [p[:2] for p in mapped_points]
print(mapped_points)

# Print the error between the destination points and the mapped points
error = np.mean(np.linalg.norm(np.array(dst_points) - np.array(mapped_points), axis=1))
print("Mean error between destination points and mapped points:", error)

# Plot the source points, destination points, and mapped points
plt.figure()
plt.plot(*zip(*src_points), 'ro-', label='Source points')
plt.plot(*zip(*dst_points), 'bo-', label='Destination points')
plt.plot(*zip(*mapped_points), 'go-', label='Mapped points')
plt.legend()
plt.show()
# Out:
# Source points:
# [(63.57813801798292, 23.08767827725804), (57.45705351987771, 2.189458195291183), (0.9527810331616093, 90.96473002039498), (36.73380115393382, 83.79968813458044)]
# Destination points:
# [(76.40625902551754, 62.81537806945913), (39.668161611323924, 36.218714807196136), (77.12597761504644, 42.169182038012345), (68.85598644349228, 86.9492288082439)]
# Mapped points:
# [array([76.40625903, 62.81537807]), array([39.66816161, 36.21871481]), array([77.12597762, 42.16918204]), array([68.85598644, 86.94922881])]
# Mean error between destination points and mapped points: 1.6349371074714836e-11

# %% [markdown]
# ## Task 3
# It's time to build something cool! One nice application of homographies is building a simple image stitcher for making panoramas.
#
# You'll reuse the routines you've written in part 1A (`calcBestHomography` and `solveAXEqualsZero`) again here, so feel free to copy over your functions directly.
#
# We're provided with three images. One large image, `im1`, is the target, i.e. we'll somehow transform and transfer two other images, `im2` and `im3` into this one.
#
# We need some way of knowing how `im2` and `im3` map into `im1`. To that end, we'll assume a user (or a feature matching alogorithm) provided us with a sets of paired points. One set links points in `im1` to points in `im2`. The other set links `im1` and `im3` in the same manner. To perform the stitch, we'll find two homographies using these point pairs, one to translate between the space in `im1` and the space in `im2` and the other for `im1` and `im3`.
#
# The end result is worth it, so don't dispair!

# %% [markdown]
# ## Import libraries

# %%
# %matplotlib inline
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio

import time

# %% [markdown]
# ## Loading and plotting images
#
# Red points show how `im2` and `im1` are related. Magenta points explain how `im1` and `im3` are related.
#
# __NOTE:__ Before you get caught out, notice that the point pairs are in X, Y format, not in R, C format. In this convention, X points run along columns from left to right and Y points run along rows from top to bottom.

# %%
# Load data
data = sio.loadmat('../dataset/PracticalData.mat', squeeze_me = True)
# Unpack data

# im1 is center image with grey background. im1 has enough space to insert im2 and im3.
im1 = data['im1']

# im2 is left image 
im2 = data['im2']

# pts1 and pts2 are matching points between image1 and image2
pts1 = data['pts1']
pts2 = data['pts2']


# im3 is right image
im3 = data['im3']
# pts1b and pts3 are matching points between image 1 and image 3
pts1b = data['pts1b']
pts3 = data['pts3']

# Show images and points
plt.imshow(im1)
plt.plot(pts1[0,:],pts1[1,:],'r.')
plt.plot(pts1b[0,:],pts1b[1,:],'m.')
plt.axis('off')
plt.show()

plt.imshow(im2)
plt.plot(pts2[0,:],pts2[1,:],'r.')
plt.axis('off')
plt.show()

plt.imshow(im3)
plt.plot(pts3[0,:],pts3[1,:],'m.')
plt.axis('off')
plt.show()

# %% [markdown]
# ## You should copy paste these functions from task2.

# %%
def solveAXEqualsZero(A):
    #TODO: Write this routine - it should solve Ah = 0. 
    # Hint: SVD will be involved. np.linalg.svd(A)
    U, S, Vh = np.linalg.svd(A)
    h = Vh[-1, :]

    return h

# %%
def calcBestHomography(pts1Cart, pts2Cart):
    
    # This function should apply the direct linear transform (DLT) algorithm to calculate the best 
    # homography that maps the cartesian points in pts1Cart to their corresonding matching cartesian poitns 
    # in pts2Cart.
    
    # This function calls solveAXEqualsZero. Make sure you are wary of how to reshape h into a 3 by 3 matrix. 

    n_points = pts1Cart.shape[1]
    
    #TODO: replace this:
    H = np.identity(3)

    #TODO: 
    # First convert points into homogeneous representation
    # Hint: we've done this before  in the skeleton code we provide.

    # Then construct the matrix A, size (n_points * 2, 9) using construct_a_from_pts
    # Consult the notes!
    A = np.zeros((2 * n_points, 9))
    for i in range(n_points):
        A[2*i:2*i+2, :] = construct_a_from_pts(pts1Cart[:, i], pts2Cart[:, i])

    # Solve Ah = 0 using solveAXEqualsZero and get h.
    h = solveAXEqualsZero(A)

    # Reshape h into the matrix H, values of h go first into rows of H
    H = h.reshape(3, 3)
    H = H / H[2, 2]
    
    return H

# %% [markdown]
# ## The Process
#
# Let's consider the first stitch, transforming and pasting `im2` into `im1`.
#
# We can loop over every location in `im1` and look in `im2` to see if there's a value we can paste in our image. The act of _looking_ into `im2` means that we need to translate from a location in `im1` to a location in `im2`. You can visualize this easily with the point correspondances already provided. For any other point in `im1`, we need a homography! You can use the function you've written before to generate this homography using `pts1` and `pts2`.
#
# So now that we have a way of going from any location in `im1` to `im2`, we can loop over the locations in `im1`, get the corresponding positions in `im2` using the homography, and copy over that pixel value at each location from `im2` to `im1`.
#
# There's one caveat, it's not always true that a transformed location from `im1` will be a valid index in `im2`, so for every index we need to check if it lies in the bounds of `im2`.
#
# Don't worry if your solution takes a while to run. For loops aren't efficient. It might take anywhere from a minute to three for each stitch. You can make this much faster, but don't worry about that right now.
#
# Again, careful of how you translate between X-Y and R-C in your code when indexing; you've been warned!

# %%
# TO DO: Calculate homography from pts1 to pts2 
HEst12 = calcBestHomography(pts2, pts1)
startTime = time.perf_counter()
#TODO: 
# For every pixel in image 1 (two loops):
    # Transform this pixel position with your homography to find where it is in the coordinates of image 2
    # Make sure you round the position using np.round since you'll use it as an index to a matrix.
    # If it the transformed position is within the boundary of image 2: 
    #     Copy pixel colour from image 2 pixel to current position in image 1 
panorama = np.copy(im1)
for i in range(im1.shape[0]):
    for j in range(im1.shape[1]):
        p = np.array([j, i, 1])
        p2 = HEst12 @ p
        p2 = np.round(p2 / p2[2]).astype(int)
        if 0 <= p2[1] < im2.shape[0] and 0 <= p2[0] < im2.shape[1]:
            panorama[i, j] = im2[p2[1], p2[0]]

print("Stitching image 2 to image 1 took: {0:.2f}s".format(time.perf_counter() - startTime))
# Out:
# Stitching image 2 to image 1 took: 6.77s

# %%
# Plot the intermediate panorama
plt.imshow(panorama)
plt.axis('off')
plt.show()

# %%
# TO DO: Repeat the above process mapping image 3 to image 1.
HEst13 = calcBestHomography(pts3, pts1b)
# Calculate homography from pts1b to pts3

startTime = time.perf_counter()
# loop and copy pixels...

for i in range(im1.shape[0]):
    for j in range(im1.shape[1]):
        p = np.array([j, i, 1])
        p3 = HEst13 @ p
        p3 = np.round(p3 / p3[2]).astype(int)
        if 0 <= p3[1] < im3.shape[0] and 0 <= p3[0] < im3.shape[1]:
            panorama[i, j] = im3[p3[1], p3[0]]

print("Stitching image 3 to image 1 took: {0:.2f}s".format(time.perf_counter() - startTime))
# Out:
# Stitching image 3 to image 1 took: 7.00s

# %%
# Plot the final panorama
plt.imshow(panorama)
plt.axis('off')
plt.show()

# %% [markdown]
# ### _Fun_ task for those who have finished all above:
#
#
# Do __NOT__ do this unless you've finished all four parts, want a challenge, and an exercise in numpy and vectorization.
#
# For loops are slow. Can you think of ways of making it faster with vectorized code? You can definitely bring it down to at least a second per stitch and maybe even lower. Speak to the TAs if you want, but you would need to figure this out for yourself as a good exercise.
#
# ### Task: How much time did you save?

# %% [markdown]
# Now, finalize and encapsule your implementation of sticking image together to a funciton for later use, vectorised stiching will save you a lot of time for the later tasks.

# %%
def stitch_image(im1, im2, H, direction='left'):
    """Stitch im2 into im1 using homography H"""
    # the direction argument is for logging only.
    startTime = time.perf_counter()
    
    
    #TODO Actual Stiching
    # For every pixel in image 1 (two loops):
        # Transform this pixel position with your homography to find where it is in the coordinates of image 2
        # Make sure you round the position using np.round since you'll use it as an index to a matrix.
        # If it the transformed position is within the boundary of image 2: 
        #     Copy pixel colour from image 2 pixel to current position in image 1
    panorama = np.copy(im1)
    for i in range(im1.shape[0]):
        for j in range(im1.shape[1]):
            p = np.array([j, i, 1])
            p2 = H @ p
            p2 = np.round(p2 / p2[2]).astype(int)
            if 0 <= p2[1] < im2.shape[0] and 0 <= p2[0] < im2.shape[1]:
                panorama[i, j] = im2[p2[1], p2[0]]
                    
    print(f"Stitching {direction} image took: {time.perf_counter() - startTime:.2f}s")
    return panorama

# Test the implementation
HEst12 = calcBestHomography(pts2, pts1)
panorama = stitch_image(im1, im2, HEst12, 'left')
plt.imshow(panorama)
plt.axis('off')
plt.show()
# Out:
# Stitching left image took: 6.50s

# %% [markdown]
# ## Task 4: Panorama Stitching with RANSAC
#
# RANSAC (Random Sample Consensus) is an iterative algorithm for robust model estimation:
# 1. Randomly select minimum number of points needed (4 points for homography)
# 2. Calculate model (homography) using these points
# 3. Count how many other points agree with this model (inliers)
# 4. Repeat steps 1-3 many times
# 5. Keep the model with the most inliers
#
# This helps remove incorrect matches (outliers) that would distort our homography estimation.
#
# ### Let's implement this step by step:

# %%
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import random

# %%
#### Common Functions
def load_and_convert_image(img):
    """Convert image to grayscale and RGB formats"""
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
    return img_gray, img_rgb

def detect_and_match(img1_gray, img2_gray, max_features=1000, ratio_thresh=0.7):
    """Detect SIFT features and match between two images"""
    # Initialize SIFT detector
    sift = cv2.SIFT_create(nfeatures=max_features)
    
    # Find keypoints and descriptors
    kp1, des1 = sift.detectAndCompute(img1_gray, None)
    kp2, des2 = sift.detectAndCompute(img2_gray, None)
    
    # Match descriptors using BFMatcher
    bf = cv2.BFMatcher()
    matches = bf.knnMatch(des1, des2, k=2)
    
    # Apply ratio test
    good_matches = []
    for m, n in matches:
        if m.distance < ratio_thresh * n.distance:
            good_matches.append(m)
            
    return kp1, kp2, good_matches

def visualize_matches(img1_rgb, img2_rgb, kp1, kp2, matches, title="Feature Matches"):
    """Visualize matches between images"""
    match_img = cv2.drawMatches(
        img1_rgb, kp1,
        img2_rgb, kp2,
        matches, None,
        flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS,
        matchColor=(0, 255, 0)
    )
    
    plt.figure(figsize=(12, 6))
    plt.imshow(match_img)
    plt.title(f"{title}\n{len(matches)} matches")
    plt.axis('off')
    plt.show()

# %%
def ransac_step1_select_points(kp1, kp2, matches):
    """Step 1: Randomly select 4 correspondences for RANSAC"""
    #TODO Convert keypoints to arrays
    src_pts = np.array([kp1[m.queryIdx].pt for m in matches])
    dst_pts = np.array([kp2[m.trainIdx].pt for m in matches])

    #TODO Randomly select 4 correspondences
    idx = random.sample(range(len(matches)), 4)
    src_sample = src_pts[idx].astype(np.float32)
    dst_sample = dst_pts[idx].astype(np.float32)

    return src_sample, dst_sample, src_pts, dst_pts

def ransac_step2_compute_inliers(src_sample, dst_sample, src_pts, dst_pts, threshold=4.0):
    """Step 2: Compute homography and calculate inliers"""
    # Compute homography using the selected 4 points
    H = cv2.getPerspectiveTransform(src_sample, dst_sample)

    #TODO Project source points using the homography
    src_pts_Hom = np.vstack([src_pts.T, np.ones(src_pts.shape[0])])
    projected_pts = H @ src_pts_Hom

    #TODO Convert back to cartesian coordinates
    projected_pts = (projected_pts[:2] / projected_pts[2]).T

    # Calculate distance between projected points and destination points
    distances = np.linalg.norm(projected_pts - dst_pts, axis=1)

    #TODO Count inliers
    inlier_matches = []
    num_inliers = 0
    for i, d in enumerate(distances):
        if d < threshold:
            inlier_matches.append(cv2.DMatch(i, i, d))
            num_inliers += 1

    return H, num_inliers, inlier_matches

def ransac_homography_manual(kp1, kp2, matches, threshold=4.0, max_iterations=2000):
    """Manually estimate homography using RANSAC"""

    # Initialize variables for the best model
    best_H = None
    max_inliers = 0
    inlier_matches = []

    for i in range(max_iterations):
        # Step 1: Select points
        src_sample, dst_sample, src_pts, dst_pts = ransac_step1_select_points(kp1, kp2, matches)

        # Step 2: Compute inliers
        H, num_inliers, current_inlier_matches = ransac_step2_compute_inliers(src_sample, dst_sample, src_pts, dst_pts, threshold)

        # Log current iteration details
        print(f"Iteration {i+1}/{max_iterations}, Num Inliers: {num_inliers}")

        #TODO Update the best model if it has more inliers
        if num_inliers > max_inliers:
            best_H = H
            max_inliers = num_inliers
            inlier_matches = current_inlier_matches


    print(f"Best model found with {max_inliers} inliers.")
    return best_H, inlier_matches

# %% [markdown]
# #### Load Images and Detect Features
# Now we are putting everything together and try the previous example with know correspondence.

# %%
# Load data
data = sio.loadmat('../dataset/PracticalData.mat', squeeze_me=True)
im1 = data['im1']  # center image
im2 = data['im2']  # left image
im3 = data['im3']  # right image

# Convert images
im1_gray, im1_rgb = load_and_convert_image(im1)
im2_gray, im2_rgb = load_and_convert_image(im2)
im3_gray, im3_rgb = load_and_convert_image(im3)

#### Match Features and Estimate Homographies
print("\n=== Matching Features between Images ===")

# Match im1 and im2
t0 = time.time()
kp1_2, kp2, matches1_2 = detect_and_match(im1_gray, im2_gray)
H1to2, inliers1_2 = ransac_homography_manual(kp1_2, kp2, matches1_2)
print(f"Image 1-2 matching time: {time.time()-t0:.3f} seconds")
print(f"Found {len(inliers1_2)} inliers out of {len(matches1_2)} matches")

# Match im1 and im3
t0 = time.time()
kp1_3, kp3, matches1_3 = detect_and_match(im1_gray, im3_gray)
H1to3, inliers1_3 = ransac_homography_manual(kp1_3, kp3, matches1_3)
print(f"Image 1-3 matching time: {time.time()-t0:.3f} seconds")
print(f"Found {len(inliers1_3)} inliers out of {len(matches1_3)} matches")

# Visualize matches
visualize_matches(im1_rgb, im2_rgb, kp1_2, kp2, inliers1_2, "Image 1-2 Inlier Matches")
visualize_matches(im1_rgb, im3_rgb, kp1_3, kp3, inliers1_3, "Image 1-3 Inlier Matches")


# Stitch images
result = im1.copy()
result = stitch_image(result, im2, H1to2, 'left')
result = stitch_image(result, im3, H1to3, 'right')

# Display final panorama
plt.figure(figsize=(15, 8))
plt.imshow(result)
plt.title("Final Panorama using SIFT and RANSAC")
plt.axis('off')
plt.show()
# Out:
# === Matching Features between Images ===
# Iteration 1/2000, Num Inliers: 114
# Iteration 2/2000, Num Inliers: 90
# Iteration 3/2000, Num Inliers: 114
# Iteration 4/2000, Num Inliers: 81
# Iteration 5/2000, Num Inliers: 113
# Iteration 6/2000, Num Inliers: 21
# Iteration 7/2000, Num Inliers: 114
# Iteration 8/2000, Num Inliers: 114
# Iteration 9/2000, Num Inliers: 61
# Iteration 10/2000, Num Inliers: 114
# Iteration 11/2000, Num Inliers: 43
# Iteration 12/2000, Num Inliers: 108
# Iteration 13/2000, Num Inliers: 45
# Iteration 14/2000, Num Inliers: 12
# Iteration 15/2000, Num Inliers: 94
# Iteration 16/2000, Num Inliers: 114
# Iteration 17/2000, Num Inliers: 88
# Iteration 18/2000, Num Inliers: 82
# Iteration 19/2000, Num Inliers: 92
# Iteration 20/2000, Num Inliers: 113
# Iteration 21/2000, Num Inliers: 72
# Iteration 22/2000, Num Inliers: 76
# Iteration 23/2000, Num Inliers: 112
# Iteration 24/2000, Num Inliers: 114
# Iteration 25/2000, Num Inliers: 71
# Iteration 26/2000, Num Inliers: 82
# Iteration 27/2000, Num Inliers: 38
# Iteration 28/2000, Num Inliers: 4
# Iteration 29/2000, Num Inliers: 7
# Iteration 30/2000, Num Inliers: 20
# Iteration 31/2000, Num Inliers: 95
# Iteration 32/2000, Num Inliers: 87
# Iteration 33/2000, Num Inliers: 4
# Iteration 34/2000, Num Inliers: 22
# Iteration 35/2000, Num Inliers: 3
# Iteration 36/2000, Num Inliers: 39
# Iteration 37/2000, Num Inliers: 6
# Iteration 38/2000, Num Inliers: 9
# Iteration 39/2000, Num Inliers: 58
# Iteration 40/2000, Num Inliers: 31
# Iteration 41/2000, Num Inliers: 32
# Iteration 42/2000, Num Inliers: 106
# Iteration 43/2000, Num Inliers: 81
# Iteration 44/2000, Num Inliers: 114
# Iteration 45/2000, Num Inliers: 114
# Iteration 46/2000, Num Inliers: 48
# Iteration 47/2000, Num Inliers: 57
# Iteration 48/2000, Num Inliers: 5
# Iteration 49/2000, Num Inliers: 9
# Iteration 50/2000, Num Inliers: 41
# Iteration 51/2000, Num Inliers: 25
# Iteration 52/2000, Num Inliers: 101
# Iteration 53/2000, Num Inliers: 47
# Iteration 54/2000, Num Inliers: 91
# Iteration 55/2000, Num Inliers: 26
# Iteration 56/2000, Num Inliers: 97
# Iteration 57/2000, Num Inliers: 85
# Iteration 58/2000, Num Inliers: 10
# Iteration 59/2000, Num Inliers: 77
# Iteration 60/2000, Num Inliers: 86
# Iteration 61/2000, Num Inliers: 114
# Iteration 62/2000, Num Inliers: 114
# Iteration 63/2000, Num Inliers: 23
# Iteration 64/2000, Num Inliers: 92
# Iteration 65/2000, Num Inliers: 46
# Iteration 66/2000, Num Inliers: 102
# Iteration 67/2000, Num Inliers: 5
# Iteration 68/2000, Num Inliers: 114
# Iteration 69/2000, Num Inliers: 64
# Iteration 70/2000, Num Inliers: 110
# Iteration 71/2000, Num Inliers: 89
# Iteration 72/2000, Num Inliers: 83
# Iteration 73/2000, Num Inliers: 92
# Iteration 74/2000, Num Inliers: 114
# Iteration 75/2000, Num Inliers: 17
# Iteration 76/2000, Num Inliers: 31
# Iteration 77/2000, Num Inliers: 114
# Iteration 78/2000, Num Inliers: 113
# Iteration 79/2000, Num Inliers: 114
# Iteration 80/2000, Num Inliers: 114
# Iteration 81/2000, Num Inliers: 81
# Iteration 82/2000, Num Inliers: 100
# Iteration 83/2000, Num Inliers: 4
# Iteration 84/2000, Num Inliers: 77
# Iteration 85/2000, Num Inliers: 106
# Iteration 86/2000, Num Inliers: 78
# Iteration 87/2000, Num Inliers: 7
# Iteration 88/2000, Num Inliers: 77
# Iteration 89/2000, Num Inliers: 114
# Iteration 90/2000, Num Inliers: 106
# Iteration 91/2000, Num Inliers: 86
# Iteration 92/2000, Num Inliers: 114
# Iteration 93/2000, Num Inliers: 96
# Iteration 94/2000, Num Inliers: 74
# Iteration 95/2000, Num Inliers: 6
# Iteration 96/2000, Num Inliers: 96
# Iteration 97/2000, Num Inliers: 14
# Iteration 98/2000, Num Inliers: 114
# Iteration 99/2000, Num Inliers: 113
# Iteration 100/2000, Num Inliers: 45
# Iteration 101/2000, Num Inliers: 98
# Iteration 102/2000, Num Inliers: 7
# Iteration 103/2000, Num Inliers: 25
# Iteration 104/2000, Num Inliers: 112
# Iteration 105/2000, Num Inliers: 10
# Iteration 106/2000, Num Inliers: 31
# Iteration 107/2000, Num Inliers: 114
# Iteration 108/2000, Num Inliers: 111
# Iteration 109/2000, Num Inliers: 5
# Iteration 110/2000, Num Inliers: 79
# Iteration 111/2000, Num Inliers: 13
# Iteration 112/2000, Num Inliers: 10
# Iteration 113/2000, Num Inliers: 94
# Iteration 114/2000, Num Inliers: 80
# Iteration 115/2000, Num Inliers: 44
# Iteration 116/2000, Num Inliers: 93
# Iteration 117/2000, Num Inliers: 90
# Iteration 118/2000, Num Inliers: 96
# Iteration 119/2000, Num Inliers: 114
# Iteration 120/2000, Num Inliers: 17
# Iteration 121/2000, Num Inliers: 5
# Iteration 122/2000, Num Inliers: 111
# Iteration 123/2000, Num Inliers: 34
# Iteration 124/2000, Num Inliers: 67
# Iteration 125/2000, Num Inliers: 114
# Iteration 126/2000, Num Inliers: 89
# Iteration 127/2000, Num Inliers: 52
# Iteration 128/2000, Num Inliers: 114
# Iteration 129/2000, Num Inliers: 4
# Iteration 130/2000, Num Inliers: 114
# Iteration 131/2000, Num Inliers: 51
# Iteration 132/2000, Num Inliers: 12
# Iteration 133/2000, Num Inliers: 114
# Iteration 134/2000, Num Inliers: 6
# Iteration 135/2000, Num Inliers: 53
# Iteration 136/2000, Num Inliers: 79
# Iteration 137/2000, Num Inliers: 114
# Iteration 138/2000, Num Inliers: 28
# Iteration 139/2000, Num Inliers: 86
# Iteration 140/2000, Num Inliers: 109
# Iteration 141/2000, Num Inliers: 77
# Iteration 142/2000, Num Inliers: 25
# Iteration 143/2000, Num Inliers: 8
# Iteration 144/2000, Num Inliers: 103
# Iteration 145/2000, Num Inliers: 76
# Iteration 146/2000, Num Inliers: 31
# Iteration 147/2000, Num Inliers: 4
# Iteration 148/2000, Num Inliers: 101
# Iteration 149/2000, Num Inliers: 4
# Iteration 150/2000, Num Inliers: 114
# Iteration 151/2000, Num Inliers: 85
# Iteration 152/2000, Num Inliers: 19
# Iteration 153/2000, Num Inliers: 57
# Iteration 154/2000, Num Inliers: 8
# Iteration 155/2000, Num Inliers: 12
# Iteration 156/2000, Num Inliers: 114
# Iteration 157/2000, Num Inliers: 70
# Iteration 158/2000, Num Inliers: 35
# Iteration 159/2000, Num Inliers: 6
# Iteration 160/2000, Num Inliers: 48
# Iteration 161/2000, Num Inliers: 42
# Iteration 162/2000, Num Inliers: 6
# Iteration 163/2000, Num Inliers: 27
# Iteration 164/2000, Num Inliers: 11
# Iteration 165/2000, Num Inliers: 109
# Iteration 166/2000, Num Inliers: 24
# Iteration 167/2000, Num Inliers: 6
# Iteration 168/2000, Num Inliers: 75
# Iteration 169/2000, Num Inliers: 67
# Iteration 170/2000, Num Inliers: 92
# Iteration 171/2000, Num Inliers: 63
# Iteration 172/2000, Num Inliers: 44
# Iteration 173/2000, Num Inliers: 6
# Iteration 174/2000, Num Inliers: 103
# Iteration 175/2000, Num Inliers: 103
# Iteration 176/2000, Num Inliers: 113
# Iteration 177/2000, Num Inliers: 36
# Iteration 178/2000, Num Inliers: 57
# Iteration 179/2000, Num Inliers: 79
# Iteration 180/2000, Num Inliers: 93
# Iteration 181/2000, Num Inliers: 94
# Iteration 182/2000, Num Inliers: 62
# Iteration 183/2000, Num Inliers: 105
# Iteration 184/2000, Num Inliers: 50
# Iteration 185/2000, Num Inliers: 0
# Iteration 186/2000, Num Inliers: 7
# Iteration 187/2000, Num Inliers: 45
# Iteration 188/2000, Num Inliers: 89
# Iteration 189/2000, Num Inliers: 60
# Iteration 190/2000, Num Inliers: 114
# Iteration 191/2000, Num Inliers: 17
# Iteration 192/2000, Num Inliers: 54
# Iteration 193/2000, Num Inliers: 113
# Iteration 194/2000, Num Inliers: 107
# Iteration 195/2000, Num Inliers: 97
# Iteration 196/2000, Num Inliers: 17
# Iteration 197/2000, Num Inliers: 43
# Iteration 198/2000, Num Inliers: 5
# Iteration 199/2000, Num Inliers: 67
# Iteration 200/2000, Num Inliers: 110
# Iteration 201/2000, Num Inliers: 32
# Iteration 202/2000, Num Inliers: 62
# Iteration 203/2000, Num Inliers: 114
# Iteration 204/2000, Num Inliers: 110
# Iteration 205/2000, Num Inliers: 111
# Iteration 206/2000, Num Inliers: 99
# Iteration 207/2000, Num Inliers: 18
# Iteration 208/2000, Num Inliers: 84
# Iteration 209/2000, Num Inliers: 6
# Iteration 210/2000, Num Inliers: 40
# Iteration 211/2000, Num Inliers: 112
# Iteration 212/2000, Num Inliers: 42
# Iteration 213/2000, Num Inliers: 4
# Iteration 214/2000, Num Inliers: 66
# Iteration 215/2000, Num Inliers: 79
# Iteration 216/2000, Num Inliers: 68
# Iteration 217/2000, Num Inliers: 13
# Iteration 218/2000, Num Inliers: 114
# Iteration 219/2000, Num Inliers: 114
# Iteration 220/2000, Num Inliers: 13
# Iteration 221/2000, Num Inliers: 111
# Iteration 222/2000, Num Inliers: 83
# Iteration 223/2000, Num Inliers: 27
# Iteration 224/2000, Num Inliers: 23
# Iteration 225/2000, Num Inliers: 96
# Iteration 226/2000, Num Inliers: 8
# Iteration 227/2000, Num Inliers: 52
# Iteration 228/2000, Num Inliers: 56
# Iteration 229/2000, Num Inliers: 79
# Iteration 230/2000, Num Inliers: 46
# Iteration 231/2000, Num Inliers: 114
# Iteration 232/2000, Num Inliers: 17
# Iteration 233/2000, Num Inliers: 42
# Iteration 234/2000, Num Inliers: 10
# Iteration 235/2000, Num Inliers: 114
# Iteration 236/2000, Num Inliers: 63
# Iteration 237/2000, Num Inliers: 113
# Iteration 238/2000, Num Inliers: 8
# Iteration 239/2000, Num Inliers: 102
# Iteration 240/2000, Num Inliers: 5
# Iteration 241/2000, Num Inliers: 12
# Iteration 242/2000, Num Inliers: 113
# Iteration 243/2000, Num Inliers: 90
# Iteration 244/2000, Num Inliers: 113
# Iteration 245/2000, Num Inliers: 104
# Iteration 246/2000, Num Inliers: 107
# Iteration 247/2000, Num Inliers: 13
# Iteration 248/2000, Num Inliers: 9
# Iteration 249/2000, Num Inliers: 89
# Iteration 250/2000, Num Inliers: 114
# Iteration 251/2000, Num Inliers: 111
# Iteration 252/2000, Num Inliers: 27
# Iteration 253/2000, Num Inliers: 48
# Iteration 254/2000, Num Inliers: 96
# Iteration 255/2000, Num Inliers: 6
# Iteration 256/2000, Num Inliers: 9
# Iteration 257/2000, Num Inliers: 80
# Iteration 258/2000, Num Inliers: 114
# Iteration 259/2000, Num Inliers: 114
# Iteration 260/2000, Num Inliers: 114
# Iteration 261/2000, Num Inliers: 19
# Iteration 262/2000, Num Inliers: 11
# Iteration 263/2000, Num Inliers: 72
# Iteration 264/2000, Num Inliers: 18
# Iteration 265/2000, Num Inliers: 9
# Iteration 266/2000, Num Inliers: 79
# Iteration 267/2000, Num Inliers: 114
# Iteration 268/2000, Num Inliers: 99
# Iteration 269/2000, Num Inliers: 55
# Iteration 270/2000, Num Inliers: 102
# Iteration 271/2000, Num Inliers: 0
# Iteration 272/2000, Num Inliers: 29
# Iteration 273/2000, Num Inliers: 0
# Iteration 274/2000, Num Inliers: 27
# Iteration 275/2000, Num Inliers: 68
# Iteration 276/2000, Num Inliers: 114
# Iteration 277/2000, Num Inliers: 11
# Iteration 278/2000, Num Inliers: 92
# Iteration 279/2000, Num Inliers: 27
# Iteration 280/2000, Num Inliers: 69
# Iteration 281/2000, Num Inliers: 87
# Iteration 282/2000, Num Inliers: 85
# Iteration 283/2000, Num Inliers: 109
# Iteration 284/2000, Num Inliers: 82
# Iteration 285/2000, Num Inliers: 114
# Iteration 286/2000, Num Inliers: 92
# Iteration 287/2000, Num Inliers: 114
# Iteration 288/2000, Num Inliers: 107
# Iteration 289/2000, Num Inliers: 91
# Iteration 290/2000, Num Inliers: 42
# Iteration 291/2000, Num Inliers: 79
# Iteration 292/2000, Num Inliers: 17
# Iteration 293/2000, Num Inliers: 97
# Iteration 294/2000, Num Inliers: 4
# Iteration 295/2000, Num Inliers: 5
# Iteration 296/2000, Num Inliers: 94
# Iteration 297/2000, Num Inliers: 89
# Iteration 298/2000, Num Inliers: 114
# Iteration 299/2000, Num Inliers: 114
# Iteration 300/2000, Num Inliers: 110
# Iteration 301/2000, Num Inliers: 98
# Iteration 302/2000, Num Inliers: 68
# Iteration 303/2000, Num Inliers: 6
# Iteration 304/2000, Num Inliers: 69
# Iteration 305/2000, Num Inliers: 25
# Iteration 306/2000, Num Inliers: 6
# Iteration 307/2000, Num Inliers: 107
# Iteration 308/2000, Num Inliers: 36
# Iteration 309/2000, Num Inliers: 9
# Iteration 310/2000, Num Inliers: 111
# Iteration 311/2000, Num Inliers: 52
# Iteration 312/2000, Num Inliers: 114
# Iteration 313/2000, Num Inliers: 114
# Iteration 314/2000, Num Inliers: 10
# Iteration 315/2000, Num Inliers: 105
# Iteration 316/2000, Num Inliers: 58
# Iteration 317/2000, Num Inliers: 114
# Iteration 318/2000, Num Inliers: 66
# Iteration 319/2000, Num Inliers: 4
# Iteration 320/2000, Num Inliers: 69
# Iteration 321/2000, Num Inliers: 73
# Iteration 322/2000, Num Inliers: 68
# Iteration 323/2000, Num Inliers: 114
# Iteration 324/2000, Num Inliers: 51
# Iteration 325/2000, Num Inliers: 113
# Iteration 326/2000, Num Inliers: 67
# Iteration 327/2000, Num Inliers: 105
# Iteration 328/2000, Num Inliers: 25
# Iteration 329/2000, Num Inliers: 47
# Iteration 330/2000, Num Inliers: 7
# Iteration 331/2000, Num Inliers: 114
# Iteration 332/2000, Num Inliers: 107
# Iteration 333/2000, Num Inliers: 110
# Iteration 334/2000, Num Inliers: 66
# Iteration 335/2000, Num Inliers: 53
# Iteration 336/2000, Num Inliers: 11
# Iteration 337/2000, Num Inliers: 80
# Iteration 338/2000, Num Inliers: 76
# Iteration 339/2000, Num Inliers: 97
# Iteration 340/2000, Num Inliers: 83
# Iteration 341/2000, Num Inliers: 39
# Iteration 342/2000, Num Inliers: 114
# Iteration 343/2000, Num Inliers: 114
# Iteration 344/2000, Num Inliers: 42
# Iteration 345/2000, Num Inliers: 102
# Iteration 346/2000, Num Inliers: 94
# Iteration 347/2000, Num Inliers: 97
# Iteration 348/2000, Num Inliers: 96
# Iteration 349/2000, Num Inliers: 6
# Iteration 350/2000, Num Inliers: 41
# Iteration 351/2000, Num Inliers: 15
# Iteration 352/2000, Num Inliers: 14
# Iteration 353/2000, Num Inliers: 46
# Iteration 354/2000, Num Inliers: 61
# Iteration 355/2000, Num Inliers: 15
# Iteration 356/2000, Num Inliers: 114
# Iteration 357/2000, Num Inliers: 25
# Iteration 358/2000, Num Inliers: 70
# Iteration 359/2000, Num Inliers: 114
# Iteration 360/2000, Num Inliers: 30
# Iteration 361/2000, Num Inliers: 71
# Iteration 362/2000, Num Inliers: 36
# Iteration 363/2000, Num Inliers: 113
# Iteration 364/2000, Num Inliers: 38
# Iteration 365/2000, Num Inliers: 86
# Iteration 366/2000, Num Inliers: 111
# Iteration 367/2000, Num Inliers: 81
# Iteration 368/2000, Num Inliers: 114
# Iteration 369/2000, Num Inliers: 79
# Iteration 370/2000, Num Inliers: 52
# Iteration 371/2000, Num Inliers: 114
# Iteration 372/2000, Num Inliers: 54
# Iteration 373/2000, Num Inliers: 110
# Iteration 374/2000, Num Inliers: 112
# Iteration 375/2000, Num Inliers: 16
# Iteration 376/2000, Num Inliers: 96
# Iteration 377/2000, Num Inliers: 44
# Iteration 378/2000, Num Inliers: 21
# Iteration 379/2000, Num Inliers: 66
# Iteration 380/2000, Num Inliers: 114
# Iteration 381/2000, Num Inliers: 14
# Iteration 382/2000, Num Inliers: 89
# Iteration 383/2000, Num Inliers: 114
# Iteration 384/2000, Num Inliers: 18
# Iteration 385/2000, Num Inliers: 43
# Iteration 386/2000, Num Inliers: 8
# Iteration 387/2000, Num Inliers: 64
# Iteration 388/2000, Num Inliers: 5
# Iteration 389/2000, Num Inliers: 114
# Iteration 390/2000, Num Inliers: 114
# Iteration 391/2000, Num Inliers: 9
# Iteration 392/2000, Num Inliers: 96
# Iteration 393/2000, Num Inliers: 38
# Iteration 394/2000, Num Inliers: 31
# Iteration 395/2000, Num Inliers: 84
# Iteration 396/2000, Num Inliers: 37
# Iteration 397/2000, Num Inliers: 17
# Iteration 398/2000, Num Inliers: 14
# Iteration 399/2000, Num Inliers: 4
# Iteration 400/2000, Num Inliers: 113
# Iteration 401/2000, Num Inliers: 110
# Iteration 402/2000, Num Inliers: 111
# Iteration 403/2000, Num Inliers: 59
# Iteration 404/2000, Num Inliers: 114
# Iteration 405/2000, Num Inliers: 104
# Iteration 406/2000, Num Inliers: 68
# Iteration 407/2000, Num Inliers: 62
# Iteration 408/2000, Num Inliers: 88
# Iteration 409/2000, Num Inliers: 101
# Iteration 410/2000, Num Inliers: 109
# Iteration 411/2000, Num Inliers: 4
# Iteration 412/2000, Num Inliers: 111
# Iteration 413/2000, Num Inliers: 7
# Iteration 414/2000, Num Inliers: 105
# Iteration 415/2000, Num Inliers: 0
# Iteration 416/2000, Num Inliers: 13
# Iteration 417/2000, Num Inliers: 87
# Iteration 418/2000, Num Inliers: 5
# Iteration 419/2000, Num Inliers: 64
# Iteration 420/2000, Num Inliers: 103
# Iteration 421/2000, Num Inliers: 81
# Iteration 422/2000, Num Inliers: 110
# Iteration 423/2000, Num Inliers: 114
# Iteration 424/2000, Num Inliers: 99
# Iteration 425/2000, Num Inliers: 5
# Iteration 426/2000, Num Inliers: 114
# Iteration 427/2000, Num Inliers: 108
# Iteration 428/2000, Num Inliers: 114
# Iteration 429/2000, Num Inliers: 13
# Iteration 430/2000, Num Inliers: 93
# Iteration 431/2000, Num Inliers: 12
# Iteration 432/2000, Num Inliers: 14
# Iteration 433/2000, Num Inliers: 103
# Iteration 434/2000, Num Inliers: 35
# Iteration 435/2000, Num Inliers: 105
# Iteration 436/2000, Num Inliers: 13
# Iteration 437/2000, Num Inliers: 9
# Iteration 438/2000, Num Inliers: 108
# Iteration 439/2000, Num Inliers: 102
# Iteration 440/2000, Num Inliers: 5
# Iteration 441/2000, Num Inliers: 30
# Iteration 442/2000, Num Inliers: 51
# Iteration 443/2000, Num Inliers: 21
# Iteration 444/2000, Num Inliers: 73
# Iteration 445/2000, Num Inliers: 113
# Iteration 446/2000, Num Inliers: 114
# Iteration 447/2000, Num Inliers: 114
# Iteration 448/2000, Num Inliers: 109
# Iteration 449/2000, Num Inliers: 114
# Iteration 450/2000, Num Inliers: 114
# Iteration 451/2000, Num Inliers: 85
# Iteration 452/2000, Num Inliers: 10
# Iteration 453/2000, Num Inliers: 11
# Iteration 454/2000, Num Inliers: 72
# Iteration 455/2000, Num Inliers: 48
# Iteration 456/2000, Num Inliers: 7
# Iteration 457/2000, Num Inliers: 12
# Iteration 458/2000, Num Inliers: 28
# Iteration 459/2000, Num Inliers: 73
# Iteration 460/2000, Num Inliers: 109
# Iteration 461/2000, Num Inliers: 76
# Iteration 462/2000, Num Inliers: 34
# Iteration 463/2000, Num Inliers: 18
# Iteration 464/2000, Num Inliers: 114
# Iteration 465/2000, Num Inliers: 107
# Iteration 466/2000, Num Inliers: 44
# Iteration 467/2000, Num Inliers: 100
# Iteration 468/2000, Num Inliers: 8
# Iteration 469/2000, Num Inliers: 104
# Iteration 470/2000, Num Inliers: 113
# Iteration 471/2000, Num Inliers: 77
# Iteration 472/2000, Num Inliers: 109
# Iteration 473/2000, Num Inliers: 32
# Iteration 474/2000, Num Inliers: 44
# Iteration 475/2000, Num Inliers: 90
# Iteration 476/2000, Num Inliers: 105
# Iteration 477/2000, Num Inliers: 17
# Iteration 478/2000, Num Inliers: 77
# Iteration 479/2000, Num Inliers: 104
# Iteration 480/2000, Num Inliers: 96
# Iteration 481/2000, Num Inliers: 12
# Iteration 482/2000, Num Inliers: 104
# Iteration 483/2000, Num Inliers: 12
# Iteration 484/2000, Num Inliers: 41
# Iteration 485/2000, Num Inliers: 114
# Iteration 486/2000, Num Inliers: 104
# Iteration 487/2000, Num Inliers: 72
# Iteration 488/2000, Num Inliers: 48
# Iteration 489/2000, Num Inliers: 113
# Iteration 490/2000, Num Inliers: 114
# Iteration 491/2000, Num Inliers: 103
# Iteration 492/2000, Num Inliers: 76
# Iteration 493/2000, Num Inliers: 68
# Iteration 494/2000, Num Inliers: 85
# Iteration 495/2000, Num Inliers: 31
# Iteration 496/2000, Num Inliers: 85
# Iteration 497/2000, Num Inliers: 5
# Iteration 498/2000, Num Inliers: 24
# Iteration 499/2000, Num Inliers: 73
# Iteration 500/2000, Num Inliers: 68
# Iteration 501/2000, Num Inliers: 114
# Iteration 502/2000, Num Inliers: 69
# Iteration 503/2000, Num Inliers: 98
# Iteration 504/2000, Num Inliers: 45
# Iteration 505/2000, Num Inliers: 43
# Iteration 506/2000, Num Inliers: 5
# Iteration 507/2000, Num Inliers: 10
# Iteration 508/2000, Num Inliers: 9
# Iteration 509/2000, Num Inliers: 4
# Iteration 510/2000, Num Inliers: 81
# Iteration 511/2000, Num Inliers: 106
# Iteration 512/2000, Num Inliers: 108
# Iteration 513/2000, Num Inliers: 114
# Iteration 514/2000, Num Inliers: 101
# Iteration 515/2000, Num Inliers: 107
# Iteration 516/2000, Num Inliers: 5
# Iteration 517/2000, Num Inliers: 20
# Iteration 518/2000, Num Inliers: 94
# Iteration 519/2000, Num Inliers: 59
# Iteration 520/2000, Num Inliers: 69
# Iteration 521/2000, Num Inliers: 110
# Iteration 522/2000, Num Inliers: 110
# Iteration 523/2000, Num Inliers: 114
# Iteration 524/2000, Num Inliers: 98
# Iteration 525/2000, Num Inliers: 4
# Iteration 526/2000, Num Inliers: 94
# Iteration 527/2000, Num Inliers: 114
# Iteration 528/2000, Num Inliers: 74
# Iteration 529/2000, Num Inliers: 88
# Iteration 530/2000, Num Inliers: 71
# Iteration 531/2000, Num Inliers: 73
# Iteration 532/2000, Num Inliers: 69
# Iteration 533/2000, Num Inliers: 28
# Iteration 534/2000, Num Inliers: 110
# Iteration 535/2000, Num Inliers: 99
# Iteration 536/2000, Num Inliers: 11
# Iteration 537/2000, Num Inliers: 80
# Iteration 538/2000, Num Inliers: 113
# Iteration 539/2000, Num Inliers: 71
# Iteration 540/2000, Num Inliers: 6
# Iteration 541/2000, Num Inliers: 80
# Iteration 542/2000, Num Inliers: 30
# Iteration 543/2000, Num Inliers: 81
# Iteration 544/2000, Num Inliers: 113
# Iteration 545/2000, Num Inliers: 44
# Iteration 546/2000, Num Inliers: 4
# Iteration 547/2000, Num Inliers: 15
# Iteration 548/2000, Num Inliers: 72
# Iteration 549/2000, Num Inliers: 76
# Iteration 550/2000, Num Inliers: 114
# Iteration 551/2000, Num Inliers: 23
# Iteration 552/2000, Num Inliers: 5
# Iteration 553/2000, Num Inliers: 11
# Iteration 554/2000, Num Inliers: 99
# Iteration 555/2000, Num Inliers: 41
# Iteration 556/2000, Num Inliers: 59
# Iteration 557/2000, Num Inliers: 90
# Iteration 558/2000, Num Inliers: 23
# Iteration 559/2000, Num Inliers: 96
# Iteration 560/2000, Num Inliers: 89
# Iteration 561/2000, Num Inliers: 96
# Iteration 562/2000, Num Inliers: 101
# Iteration 563/2000, Num Inliers: 102
# Iteration 564/2000, Num Inliers: 20
# Iteration 565/2000, Num Inliers: 31
# Iteration 566/2000, Num Inliers: 28
# Iteration 567/2000, Num Inliers: 114
# Iteration 568/2000, Num Inliers: 108
# Iteration 569/2000, Num Inliers: 114
# Iteration 570/2000, Num Inliers: 5
# Iteration 571/2000, Num Inliers: 89
# Iteration 572/2000, Num Inliers: 30
# Iteration 573/2000, Num Inliers: 53
# Iteration 574/2000, Num Inliers: 114
# Iteration 575/2000, Num Inliers: 70
# Iteration 576/2000, Num Inliers: 64
# Iteration 577/2000, Num Inliers: 113
# Iteration 578/2000, Num Inliers: 30
# Iteration 579/2000, Num Inliers: 88
# Iteration 580/2000, Num Inliers: 61
# Iteration 581/2000, Num Inliers: 103
# Iteration 582/2000, Num Inliers: 6
# Iteration 583/2000, Num Inliers: 5
# Iteration 584/2000, Num Inliers: 114
# Iteration 585/2000, Num Inliers: 58
# Iteration 586/2000, Num Inliers: 31
# Iteration 587/2000, Num Inliers: 25
# Iteration 588/2000, Num Inliers: 102
# Iteration 589/2000, Num Inliers: 114
# Iteration 590/2000, Num Inliers: 113
# Iteration 591/2000, Num Inliers: 80
# Iteration 592/2000, Num Inliers: 114
# Iteration 593/2000, Num Inliers: 50
# Iteration 594/2000, Num Inliers: 68
# Iteration 595/2000, Num Inliers: 114
# Iteration 596/2000, Num Inliers: 113
# Iteration 597/2000, Num Inliers: 94
# Iteration 598/2000, Num Inliers: 92
# Iteration 599/2000, Num Inliers: 113
# Iteration 600/2000, Num Inliers: 57
# Iteration 601/2000, Num Inliers: 47
# Iteration 602/2000, Num Inliers: 111
# Iteration 603/2000, Num Inliers: 6
# Iteration 604/2000, Num Inliers: 69
# Iteration 605/2000, Num Inliers: 6
# Iteration 606/2000, Num Inliers: 62
# Iteration 607/2000, Num Inliers: 114
# Iteration 608/2000, Num Inliers: 108
# Iteration 609/2000, Num Inliers: 17
# Iteration 610/2000, Num Inliers: 39
# Iteration 611/2000, Num Inliers: 99
# Iteration 612/2000, Num Inliers: 114
# Iteration 613/2000, Num Inliers: 34
# Iteration 614/2000, Num Inliers: 112
# Iteration 615/2000, Num Inliers: 29
# Iteration 616/2000, Num Inliers: 4
# Iteration 617/2000, Num Inliers: 21
# Iteration 618/2000, Num Inliers: 33
# Iteration 619/2000, Num Inliers: 53
# Iteration 620/2000, Num Inliers: 63
# Iteration 621/2000, Num Inliers: 74
# Iteration 622/2000, Num Inliers: 99
# Iteration 623/2000, Num Inliers: 80
# Iteration 624/2000, Num Inliers: 5
# Iteration 625/2000, Num Inliers: 14
# Iteration 626/2000, Num Inliers: 113
# Iteration 627/2000, Num Inliers: 113
# Iteration 628/2000, Num Inliers: 8
# Iteration 629/2000, Num Inliers: 80
# Iteration 630/2000, Num Inliers: 6
# Iteration 631/2000, Num Inliers: 18
# Iteration 632/2000, Num Inliers: 111
# Iteration 633/2000, Num Inliers: 96
# Iteration 634/2000, Num Inliers: 57
# Iteration 635/2000, Num Inliers: 114
# Iteration 636/2000, Num Inliers: 112
# Iteration 637/2000, Num Inliers: 87
# Iteration 638/2000, Num Inliers: 114
# Iteration 639/2000, Num Inliers: 4
# Iteration 640/2000, Num Inliers: 102
# Iteration 641/2000, Num Inliers: 49
# Iteration 642/2000, Num Inliers: 22
# Iteration 643/2000, Num Inliers: 114
# Iteration 644/2000, Num Inliers: 35
# Iteration 645/2000, Num Inliers: 74
# Iteration 646/2000, Num Inliers: 114
# Iteration 647/2000, Num Inliers: 87
# Iteration 648/2000, Num Inliers: 30
# Iteration 649/2000, Num Inliers: 4
# Iteration 650/2000, Num Inliers: 65
# Iteration 651/2000, Num Inliers: 114
# Iteration 652/2000, Num Inliers: 113
# Iteration 653/2000, Num Inliers: 54
# Iteration 654/2000, Num Inliers: 95
# Iteration 655/2000, Num Inliers: 104
# Iteration 656/2000, Num Inliers: 91
# Iteration 657/2000, Num Inliers: 12
# Iteration 658/2000, Num Inliers: 32
# Iteration 659/2000, Num Inliers: 40
# Iteration 660/2000, Num Inliers: 49
# Iteration 661/2000, Num Inliers: 114
# Iteration 662/2000, Num Inliers: 16
# Iteration 663/2000, Num Inliers: 55
# Iteration 664/2000, Num Inliers: 114
# Iteration 665/2000, Num Inliers: 93
# Iteration 666/2000, Num Inliers: 16
# Iteration 667/2000, Num Inliers: 114
# Iteration 668/2000, Num Inliers: 86
# Iteration 669/2000, Num Inliers: 5
# Iteration 670/2000, Num Inliers: 28
# Iteration 671/2000, Num Inliers: 52
# Iteration 672/2000, Num Inliers: 114
# Iteration 673/2000, Num Inliers: 28
# Iteration 674/2000, Num Inliers: 102
# Iteration 675/2000, Num Inliers: 57
# Iteration 676/2000, Num Inliers: 5
# Iteration 677/2000, Num Inliers: 110
# Iteration 678/2000, Num Inliers: 114
# Iteration 679/2000, Num Inliers: 114
# Iteration 680/2000, Num Inliers: 34
# Iteration 681/2000, Num Inliers: 71
# Iteration 682/2000, Num Inliers: 66
# Iteration 683/2000, Num Inliers: 24
# Iteration 684/2000, Num Inliers: 114
# Iteration 685/2000, Num Inliers: 111
# Iteration 686/2000, Num Inliers: 9
# Iteration 687/2000, Num Inliers: 75
# Iteration 688/2000, Num Inliers: 5
# Iteration 689/2000, Num Inliers: 8
# Iteration 690/2000, Num Inliers: 48
# Iteration 691/2000, Num Inliers: 22
# Iteration 692/2000, Num Inliers: 114
# Iteration 693/2000, Num Inliers: 57
# Iteration 694/2000, Num Inliers: 87
# Iteration 695/2000, Num Inliers: 17
# Iteration 696/2000, Num Inliers: 114
# Iteration 697/2000, Num Inliers: 4
# Iteration 698/2000, Num Inliers: 34
# Iteration 699/2000, Num Inliers: 34
# Iteration 700/2000, Num Inliers: 103
# Iteration 701/2000, Num Inliers: 72
# Iteration 702/2000, Num Inliers: 114
# Iteration 703/2000, Num Inliers: 21
# Iteration 704/2000, Num Inliers: 101
# Iteration 705/2000, Num Inliers: 87
# Iteration 706/2000, Num Inliers: 110
# Iteration 707/2000, Num Inliers: 72
# Iteration 708/2000, Num Inliers: 30
# Iteration 709/2000, Num Inliers: 114
# Iteration 710/2000, Num Inliers: 83
# Iteration 711/2000, Num Inliers: 9
# Iteration 712/2000, Num Inliers: 65
# Iteration 713/2000, Num Inliers: 26
# Iteration 714/2000, Num Inliers: 15
# Iteration 715/2000, Num Inliers: 34
# Iteration 716/2000, Num Inliers: 13
# Iteration 717/2000, Num Inliers: 114
# Iteration 718/2000, Num Inliers: 39
# Iteration 719/2000, Num Inliers: 113
# Iteration 720/2000, Num Inliers: 114
# Iteration 721/2000, Num Inliers: 96
# Iteration 722/2000, Num Inliers: 20
# Iteration 723/2000, Num Inliers: 0
# Iteration 724/2000, Num Inliers: 49
# Iteration 725/2000, Num Inliers: 114
# Iteration 726/2000, Num Inliers: 12
# Iteration 727/2000, Num Inliers: 40
# Iteration 728/2000, Num Inliers: 15
# Iteration 729/2000, Num Inliers: 86
# Iteration 730/2000, Num Inliers: 34
# Iteration 731/2000, Num Inliers: 114
# Iteration 732/2000, Num Inliers: 114
# Iteration 733/2000, Num Inliers: 20
# Iteration 734/2000, Num Inliers: 92
# Iteration 735/2000, Num Inliers: 114
# Iteration 736/2000, Num Inliers: 6
# Iteration 737/2000, Num Inliers: 76
# Iteration 738/2000, Num Inliers: 64
# Iteration 739/2000, Num Inliers: 20
# Iteration 740/2000, Num Inliers: 6
# Iteration 741/2000, Num Inliers: 114
# Iteration 742/2000, Num Inliers: 65
# Iteration 743/2000, Num Inliers: 76
# Iteration 744/2000, Num Inliers: 114
# Iteration 745/2000, Num Inliers: 114
# Iteration 746/2000, Num Inliers: 34
# Iteration 747/2000, Num Inliers: 113
# Iteration 748/2000, Num Inliers: 31
# Iteration 749/2000, Num Inliers: 82
# Iteration 750/2000, Num Inliers: 113
# Iteration 751/2000, Num Inliers: 85
# Iteration 752/2000, Num Inliers: 61
# Iteration 753/2000, Num Inliers: 114
# Iteration 754/2000, Num Inliers: 68
# Iteration 755/2000, Num Inliers: 66
# Iteration 756/2000, Num Inliers: 5
# Iteration 757/2000, Num Inliers: 78
# Iteration 758/2000, Num Inliers: 104
# Iteration 759/2000, Num Inliers: 42
# Iteration 760/2000, Num Inliers: 35
# Iteration 761/2000, Num Inliers: 59
# Iteration 762/2000, Num Inliers: 19
# Iteration 763/2000, Num Inliers: 114
# Iteration 764/2000, Num Inliers: 111
# Iteration 765/2000, Num Inliers: 8
# Iteration 766/2000, Num Inliers: 93
# Iteration 767/2000, Num Inliers: 114
# Iteration 768/2000, Num Inliers: 113
# Iteration 769/2000, Num Inliers: 4
# Iteration 770/2000, Num Inliers: 4
# Iteration 771/2000, Num Inliers: 114
# Iteration 772/2000, Num Inliers: 114
# Iteration 773/2000, Num Inliers: 112
# Iteration 774/2000, Num Inliers: 92
# Iteration 775/2000, Num Inliers: 88
# Iteration 776/2000, Num Inliers: 77
# Iteration 777/2000, Num Inliers: 72
# Iteration 778/2000, Num Inliers: 102
# Iteration 779/2000, Num Inliers: 4
# Iteration 780/2000, Num Inliers: 14
# Iteration 781/2000, Num Inliers: 29
# Iteration 782/2000, Num Inliers: 106
# Iteration 783/2000, Num Inliers: 5
# Iteration 784/2000, Num Inliers: 5
# Iteration 785/2000, Num Inliers: 113
# Iteration 786/2000, Num Inliers: 64
# Iteration 787/2000, Num Inliers: 98
# Iteration 788/2000, Num Inliers: 4
# Iteration 789/2000, Num Inliers: 35
# Iteration 790/2000, Num Inliers: 92
# Iteration 791/2000, Num Inliers: 57
# Iteration 792/2000, Num Inliers: 79
# Iteration 793/2000, Num Inliers: 19
# Iteration 794/2000, Num Inliers: 5
# Iteration 795/2000, Num Inliers: 11
# Iteration 796/2000, Num Inliers: 28
# Iteration 797/2000, Num Inliers: 89
# Iteration 798/2000, Num Inliers: 88
# Iteration 799/2000, Num Inliers: 114
# Iteration 800/2000, Num Inliers: 20
# Iteration 801/2000, Num Inliers: 10
# Iteration 802/2000, Num Inliers: 75
# Iteration 803/2000, Num Inliers: 49
# Iteration 804/2000, Num Inliers: 14
# Iteration 805/2000, Num Inliers: 42
# Iteration 806/2000, Num Inliers: 10
# Iteration 807/2000, Num Inliers: 6
# Iteration 808/2000, Num Inliers: 114
# Iteration 809/2000, Num Inliers: 19
# Iteration 810/2000, Num Inliers: 41
# Iteration 811/2000, Num Inliers: 22
# Iteration 812/2000, Num Inliers: 7
# Iteration 813/2000, Num Inliers: 93
# Iteration 814/2000, Num Inliers: 27
# Iteration 815/2000, Num Inliers: 4
# Iteration 816/2000, Num Inliers: 112
# Iteration 817/2000, Num Inliers: 9
# Iteration 818/2000, Num Inliers: 114
# Iteration 819/2000, Num Inliers: 4
# Iteration 820/2000, Num Inliers: 71
# Iteration 821/2000, Num Inliers: 114
# Iteration 822/2000, Num Inliers: 111
# Iteration 823/2000, Num Inliers: 39
# Iteration 824/2000, Num Inliers: 114
# Iteration 825/2000, Num Inliers: 27
# Iteration 826/2000, Num Inliers: 114
# Iteration 827/2000, Num Inliers: 38
# Iteration 828/2000, Num Inliers: 114
# Iteration 829/2000, Num Inliers: 8
# Iteration 830/2000, Num Inliers: 114
# Iteration 831/2000, Num Inliers: 37
# Iteration 832/2000, Num Inliers: 107
# Iteration 833/2000, Num Inliers: 105
# Iteration 834/2000, Num Inliers: 90
# Iteration 835/2000, Num Inliers: 39
# Iteration 836/2000, Num Inliers: 22
# Iteration 837/2000, Num Inliers: 26
# Iteration 838/2000, Num Inliers: 71
# Iteration 839/2000, Num Inliers: 78
# Iteration 840/2000, Num Inliers: 5
# Iteration 841/2000, Num Inliers: 92
# Iteration 842/2000, Num Inliers: 45
# Iteration 843/2000, Num Inliers: 114
# Iteration 844/2000, Num Inliers: 8
# Iteration 845/2000, Num Inliers: 91
# Iteration 846/2000, Num Inliers: 23
# Iteration 847/2000, Num Inliers: 114
# Iteration 848/2000, Num Inliers: 99
# Iteration 849/2000, Num Inliers: 16
# Iteration 850/2000, Num Inliers: 22
# Iteration 851/2000, Num Inliers: 114
# Iteration 852/2000, Num Inliers: 114
# Iteration 853/2000, Num Inliers: 101
# Iteration 854/2000, Num Inliers: 114
# Iteration 855/2000, Num Inliers: 104
# Iteration 856/2000, Num Inliers: 62
# Iteration 857/2000, Num Inliers: 93
# Iteration 858/2000, Num Inliers: 47
# Iteration 859/2000, Num Inliers: 38
# Iteration 860/2000, Num Inliers: 86
# Iteration 861/2000, Num Inliers: 109
# Iteration 862/2000, Num Inliers: 7
# Iteration 863/2000, Num Inliers: 100
# Iteration 864/2000, Num Inliers: 21
# Iteration 865/2000, Num Inliers: 37
# Iteration 866/2000, Num Inliers: 9
# Iteration 867/2000, Num Inliers: 21
# Iteration 868/2000, Num Inliers: 114
# Iteration 869/2000, Num Inliers: 14
# Iteration 870/2000, Num Inliers: 47
# Iteration 871/2000, Num Inliers: 32
# Iteration 872/2000, Num Inliers: 41
# Iteration 873/2000, Num Inliers: 104
# Iteration 874/2000, Num Inliers: 114
# Iteration 875/2000, Num Inliers: 23
# Iteration 876/2000, Num Inliers: 51
# Iteration 877/2000, Num Inliers: 20
# Iteration 878/2000, Num Inliers: 99
# Iteration 879/2000, Num Inliers: 57
# Iteration 880/2000, Num Inliers: 113
# Iteration 881/2000, Num Inliers: 110
# Iteration 882/2000, Num Inliers: 114
# Iteration 883/2000, Num Inliers: 11
# Iteration 884/2000, Num Inliers: 104
# Iteration 885/2000, Num Inliers: 15
# Iteration 886/2000, Num Inliers: 114
# Iteration 887/2000, Num Inliers: 10
# Iteration 888/2000, Num Inliers: 110
# Iteration 889/2000, Num Inliers: 78
# Iteration 890/2000, Num Inliers: 10
# Iteration 891/2000, Num Inliers: 35
# Iteration 892/2000, Num Inliers: 0
# Iteration 893/2000, Num Inliers: 82
# Iteration 894/2000, Num Inliers: 59
# Iteration 895/2000, Num Inliers: 108
# Iteration 896/2000, Num Inliers: 9
# Iteration 897/2000, Num Inliers: 114
# Iteration 898/2000, Num Inliers: 94
# Iteration 899/2000, Num Inliers: 112
# Iteration 900/2000, Num Inliers: 87
# Iteration 901/2000, Num Inliers: 66
# Iteration 902/2000, Num Inliers: 104
# Iteration 903/2000, Num Inliers: 59
# Iteration 904/2000, Num Inliers: 87
# Iteration 905/2000, Num Inliers: 92
# Iteration 906/2000, Num Inliers: 101
# Iteration 907/2000, Num Inliers: 5
# Iteration 908/2000, Num Inliers: 66
# Iteration 909/2000, Num Inliers: 113
# Iteration 910/2000, Num Inliers: 5
# Iteration 911/2000, Num Inliers: 13
# Iteration 912/2000, Num Inliers: 90
# Iteration 913/2000, Num Inliers: 22
# Iteration 914/2000, Num Inliers: 4
# Iteration 915/2000, Num Inliers: 4
# Iteration 916/2000, Num Inliers: 73
# Iteration 917/2000, Num Inliers: 22
# Iteration 918/2000, Num Inliers: 29
# Iteration 919/2000, Num Inliers: 114
# Iteration 920/2000, Num Inliers: 5
# Iteration 921/2000, Num Inliers: 5
# Iteration 922/2000, Num Inliers: 7
# Iteration 923/2000, Num Inliers: 7
# Iteration 924/2000, Num Inliers: 11
# Iteration 925/2000, Num Inliers: 113
# Iteration 926/2000, Num Inliers: 68
# Iteration 927/2000, Num Inliers: 11
# Iteration 928/2000, Num Inliers: 7
# Iteration 929/2000, Num Inliers: 113
# Iteration 930/2000, Num Inliers: 114
# Iteration 931/2000, Num Inliers: 102
# Iteration 932/2000, Num Inliers: 110
# Iteration 933/2000, Num Inliers: 4
# Iteration 934/2000, Num Inliers: 99
# Iteration 935/2000, Num Inliers: 5
# Iteration 936/2000, Num Inliers: 20
# Iteration 937/2000, Num Inliers: 93
# Iteration 938/2000, Num Inliers: 67
# Iteration 939/2000, Num Inliers: 114
# Iteration 940/2000, Num Inliers: 114
# Iteration 941/2000, Num Inliers: 26
# Iteration 942/2000, Num Inliers: 5
# Iteration 943/2000, Num Inliers: 87
# Iteration 944/2000, Num Inliers: 11
# Iteration 945/2000, Num Inliers: 113
# Iteration 946/2000, Num Inliers: 94
# Iteration 947/2000, Num Inliers: 13
# Iteration 948/2000, Num Inliers: 114
# Iteration 949/2000, Num Inliers: 83
# Iteration 950/2000, Num Inliers: 101
# Iteration 951/2000, Num Inliers: 29
# Iteration 952/2000, Num Inliers: 41
# Iteration 953/2000, Num Inliers: 73
# Iteration 954/2000, Num Inliers: 25
# Iteration 955/2000, Num Inliers: 41
# Iteration 956/2000, Num Inliers: 114
# Iteration 957/2000, Num Inliers: 67
# Iteration 958/2000, Num Inliers: 45
# Iteration 959/2000, Num Inliers: 93
# Iteration 960/2000, Num Inliers: 72
# Iteration 961/2000, Num Inliers: 114
# Iteration 962/2000, Num Inliers: 91
# Iteration 963/2000, Num Inliers: 29
# Iteration 964/2000, Num Inliers: 7
# Iteration 965/2000, Num Inliers: 4
# Iteration 966/2000, Num Inliers: 98
# Iteration 967/2000, Num Inliers: 86
# Iteration 968/2000, Num Inliers: 113
# Iteration 969/2000, Num Inliers: 12
# Iteration 970/2000, Num Inliers: 79
# Iteration 971/2000, Num Inliers: 81
# Iteration 972/2000, Num Inliers: 23
# Iteration 973/2000, Num Inliers: 114
# Iteration 974/2000, Num Inliers: 113
# Iteration 975/2000, Num Inliers: 71
# Iteration 976/2000, Num Inliers: 6
# Iteration 977/2000, Num Inliers: 9
# Iteration 978/2000, Num Inliers: 114
# Iteration 979/2000, Num Inliers: 20
# Iteration 980/2000, Num Inliers: 105
# Iteration 981/2000, Num Inliers: 81
# Iteration 982/2000, Num Inliers: 5
# Iteration 983/2000, Num Inliers: 87
# Iteration 984/2000, Num Inliers: 75
# Iteration 985/2000, Num Inliers: 42
# Iteration 986/2000, Num Inliers: 4
# Iteration 987/2000, Num Inliers: 9
# Iteration 988/2000, Num Inliers: 114
# Iteration 989/2000, Num Inliers: 84
# Iteration 990/2000, Num Inliers: 101
# Iteration 991/2000, Num Inliers: 32
# Iteration 992/2000, Num Inliers: 114
# Iteration 993/2000, Num Inliers: 110
# Iteration 994/2000, Num Inliers: 8
# Iteration 995/2000, Num Inliers: 30
# Iteration 996/2000, Num Inliers: 63
# Iteration 997/2000, Num Inliers: 35
# Iteration 998/2000, Num Inliers: 106
# Iteration 999/2000, Num Inliers: 27
# Iteration 1000/2000, Num Inliers: 4
# Iteration 1001/2000, Num Inliers: 114
# Iteration 1002/2000, Num Inliers: 96
# Iteration 1003/2000, Num Inliers: 114
# Iteration 1004/2000, Num Inliers: 99
# Iteration 1005/2000, Num Inliers: 6
# Iteration 1006/2000, Num Inliers: 99
# Iteration 1007/2000, Num Inliers: 113
# Iteration 1008/2000, Num Inliers: 99
# Iteration 1009/2000, Num Inliers: 10
# Iteration 1010/2000, Num Inliers: 65
# Iteration 1011/2000, Num Inliers: 21
# Iteration 1012/2000, Num Inliers: 44
# Iteration 1013/2000, Num Inliers: 55
# Iteration 1014/2000, Num Inliers: 33
# Iteration 1015/2000, Num Inliers: 34
# Iteration 1016/2000, Num Inliers: 92
# Iteration 1017/2000, Num Inliers: 70
# Iteration 1018/2000, Num Inliers: 114
# Iteration 1019/2000, Num Inliers: 6
# Iteration 1020/2000, Num Inliers: 4
# Iteration 1021/2000, Num Inliers: 44
# Iteration 1022/2000, Num Inliers: 12
# Iteration 1023/2000, Num Inliers: 80
# Iteration 1024/2000, Num Inliers: 42
# Iteration 1025/2000, Num Inliers: 6
# Iteration 1026/2000, Num Inliers: 13
# Iteration 1027/2000, Num Inliers: 89
# Iteration 1028/2000, Num Inliers: 14
# Iteration 1029/2000, Num Inliers: 51
# Iteration 1030/2000, Num Inliers: 114
# Iteration 1031/2000, Num Inliers: 92
# Iteration 1032/2000, Num Inliers: 24
# Iteration 1033/2000, Num Inliers: 94
# Iteration 1034/2000, Num Inliers: 12
# Iteration 1035/2000, Num Inliers: 92
# Iteration 1036/2000, Num Inliers: 26
# Iteration 1037/2000, Num Inliers: 103
# Iteration 1038/2000, Num Inliers: 8
# Iteration 1039/2000, Num Inliers: 74
# Iteration 1040/2000, Num Inliers: 77
# Iteration 1041/2000, Num Inliers: 114
# Iteration 1042/2000, Num Inliers: 84
# Iteration 1043/2000, Num Inliers: 21
# Iteration 1044/2000, Num Inliers: 79
# Iteration 1045/2000, Num Inliers: 19
# Iteration 1046/2000, Num Inliers: 95
# Iteration 1047/2000, Num Inliers: 30
# Iteration 1048/2000, Num Inliers: 47
# Iteration 1049/2000, Num Inliers: 98
# Iteration 1050/2000, Num Inliers: 7
# Iteration 1051/2000, Num Inliers: 8
# Iteration 1052/2000, Num Inliers: 114
# Iteration 1053/2000, Num Inliers: 89
# Iteration 1054/2000, Num Inliers: 102
# Iteration 1055/2000, Num Inliers: 53
# Iteration 1056/2000, Num Inliers: 84
# Iteration 1057/2000, Num Inliers: 114
# Iteration 1058/2000, Num Inliers: 45
# Iteration 1059/2000, Num Inliers: 19
# Iteration 1060/2000, Num Inliers: 103
# Iteration 1061/2000, Num Inliers: 112
# Iteration 1062/2000, Num Inliers: 84
# Iteration 1063/2000, Num Inliers: 88
# Iteration 1064/2000, Num Inliers: 8
# Iteration 1065/2000, Num Inliers: 114
# Iteration 1066/2000, Num Inliers: 114
# Iteration 1067/2000, Num Inliers: 94
# Iteration 1068/2000, Num Inliers: 9
# Iteration 1069/2000, Num Inliers: 90
# Iteration 1070/2000, Num Inliers: 105
# Iteration 1071/2000, Num Inliers: 83
# Iteration 1072/2000, Num Inliers: 114
# Iteration 1073/2000, Num Inliers: 92
# Iteration 1074/2000, Num Inliers: 44
# Iteration 1075/2000, Num Inliers: 29
# Iteration 1076/2000, Num Inliers: 114
# Iteration 1077/2000, Num Inliers: 74
# Iteration 1078/2000, Num Inliers: 110
# Iteration 1079/2000, Num Inliers: 11
# Iteration 1080/2000, Num Inliers: 26
# Iteration 1081/2000, Num Inliers: 114
# Iteration 1082/2000, Num Inliers: 77
# Iteration 1083/2000, Num Inliers: 6
# Iteration 1084/2000, Num Inliers: 89
# Iteration 1085/2000, Num Inliers: 89
# Iteration 1086/2000, Num Inliers: 34
# Iteration 1087/2000, Num Inliers: 77
# Iteration 1088/2000, Num Inliers: 114
# Iteration 1089/2000, Num Inliers: 87
# Iteration 1090/2000, Num Inliers: 80
# Iteration 1091/2000, Num Inliers: 5
# Iteration 1092/2000, Num Inliers: 5
# Iteration 1093/2000, Num Inliers: 48
# Iteration 1094/2000, Num Inliers: 114
# Iteration 1095/2000, Num Inliers: 27
# Iteration 1096/2000, Num Inliers: 6
# Iteration 1097/2000, Num Inliers: 11
# Iteration 1098/2000, Num Inliers: 34
# Iteration 1099/2000, Num Inliers: 101
# Iteration 1100/2000, Num Inliers: 69
# Iteration 1101/2000, Num Inliers: 89
# Iteration 1102/2000, Num Inliers: 114
# Iteration 1103/2000, Num Inliers: 105
# Iteration 1104/2000, Num Inliers: 107
# Iteration 1105/2000, Num Inliers: 6
# Iteration 1106/2000, Num Inliers: 5
# Iteration 1107/2000, Num Inliers: 71
# Iteration 1108/2000, Num Inliers: 8
# Iteration 1109/2000, Num Inliers: 26
# Iteration 1110/2000, Num Inliers: 23
# Iteration 1111/2000, Num Inliers: 114
# Iteration 1112/2000, Num Inliers: 8
# Iteration 1113/2000, Num Inliers: 56
# Iteration 1114/2000, Num Inliers: 92
# Iteration 1115/2000, Num Inliers: 64
# Iteration 1116/2000, Num Inliers: 4
# Iteration 1117/2000, Num Inliers: 96
# Iteration 1118/2000, Num Inliers: 49
# Iteration 1119/2000, Num Inliers: 63
# Iteration 1120/2000, Num Inliers: 4
# Iteration 1121/2000, Num Inliers: 21
# Iteration 1122/2000, Num Inliers: 78
# Iteration 1123/2000, Num Inliers: 38
# Iteration 1124/2000, Num Inliers: 20
# Iteration 1125/2000, Num Inliers: 114
# Iteration 1126/2000, Num Inliers: 113
# Iteration 1127/2000, Num Inliers: 114
# Iteration 1128/2000, Num Inliers: 5
# Iteration 1129/2000, Num Inliers: 62
# Iteration 1130/2000, Num Inliers: 4
# Iteration 1131/2000, Num Inliers: 4
# Iteration 1132/2000, Num Inliers: 8
# Iteration 1133/2000, Num Inliers: 96
# Iteration 1134/2000, Num Inliers: 10
# Iteration 1135/2000, Num Inliers: 114
# Iteration 1136/2000, Num Inliers: 114
# Iteration 1137/2000, Num Inliers: 103
# Iteration 1138/2000, Num Inliers: 11
# Iteration 1139/2000, Num Inliers: 114
# Iteration 1140/2000, Num Inliers: 111
# Iteration 1141/2000, Num Inliers: 114
# Iteration 1142/2000, Num Inliers: 114
# Iteration 1143/2000, Num Inliers: 114
# Iteration 1144/2000, Num Inliers: 114
# Iteration 1145/2000, Num Inliers: 84
# Iteration 1146/2000, Num Inliers: 114
# Iteration 1147/2000, Num Inliers: 15
# Iteration 1148/2000, Num Inliers: 114
# Iteration 1149/2000, Num Inliers: 114
# Iteration 1150/2000, Num Inliers: 50
# Iteration 1151/2000, Num Inliers: 113
# Iteration 1152/2000, Num Inliers: 72
# Iteration 1153/2000, Num Inliers: 98
# Iteration 1154/2000, Num Inliers: 4
# Iteration 1155/2000, Num Inliers: 49
# Iteration 1156/2000, Num Inliers: 113
# Iteration 1157/2000, Num Inliers: 40
# Iteration 1158/2000, Num Inliers: 114
# Iteration 1159/2000, Num Inliers: 25
# Iteration 1160/2000, Num Inliers: 85
# Iteration 1161/2000, Num Inliers: 114
# Iteration 1162/2000, Num Inliers: 71
# Iteration 1163/2000, Num Inliers: 20
# Iteration 1164/2000, Num Inliers: 114
# Iteration 1165/2000, Num Inliers: 114
# Iteration 1166/2000, Num Inliers: 94
# Iteration 1167/2000, Num Inliers: 4
# Iteration 1168/2000, Num Inliers: 71
# Iteration 1169/2000, Num Inliers: 18
# Iteration 1170/2000, Num Inliers: 114
# Iteration 1171/2000, Num Inliers: 46
# Iteration 1172/2000, Num Inliers: 7
# Iteration 1173/2000, Num Inliers: 31
# Iteration 1174/2000, Num Inliers: 30
# Iteration 1175/2000, Num Inliers: 86
# Iteration 1176/2000, Num Inliers: 59
# Iteration 1177/2000, Num Inliers: 42
# Iteration 1178/2000, Num Inliers: 9
# Iteration 1179/2000, Num Inliers: 55
# Iteration 1180/2000, Num Inliers: 26
# Iteration 1181/2000, Num Inliers: 29
# Iteration 1182/2000, Num Inliers: 76
# Iteration 1183/2000, Num Inliers: 66
# Iteration 1184/2000, Num Inliers: 19
# Iteration 1185/2000, Num Inliers: 114
# Iteration 1186/2000, Num Inliers: 114
# Iteration 1187/2000, Num Inliers: 54
# Iteration 1188/2000, Num Inliers: 51
# Iteration 1189/2000, Num Inliers: 4
# Iteration 1190/2000, Num Inliers: 10
# Iteration 1191/2000, Num Inliers: 45
# Iteration 1192/2000, Num Inliers: 35
# Iteration 1193/2000, Num Inliers: 27
# Iteration 1194/2000, Num Inliers: 113
# Iteration 1195/2000, Num Inliers: 114
# Iteration 1196/2000, Num Inliers: 5
# Iteration 1197/2000, Num Inliers: 112
# Iteration 1198/2000, Num Inliers: 11
# Iteration 1199/2000, Num Inliers: 101
# Iteration 1200/2000, Num Inliers: 5
# Iteration 1201/2000, Num Inliers: 21
# Iteration 1202/2000, Num Inliers: 88
# Iteration 1203/2000, Num Inliers: 93
# Iteration 1204/2000, Num Inliers: 113
# Iteration 1205/2000, Num Inliers: 25
# Iteration 1206/2000, Num Inliers: 66
# Iteration 1207/2000, Num Inliers: 78
# Iteration 1208/2000, Num Inliers: 105
# Iteration 1209/2000, Num Inliers: 113
# Iteration 1210/2000, Num Inliers: 5
# Iteration 1211/2000, Num Inliers: 47
# Iteration 1212/2000, Num Inliers: 19
# Iteration 1213/2000, Num Inliers: 114
# Iteration 1214/2000, Num Inliers: 65
# Iteration 1215/2000, Num Inliers: 59
# Iteration 1216/2000, Num Inliers: 8
# Iteration 1217/2000, Num Inliers: 113
# Iteration 1218/2000, Num Inliers: 114
# Iteration 1219/2000, Num Inliers: 97
# Iteration 1220/2000, Num Inliers: 88
# Iteration 1221/2000, Num Inliers: 58
# Iteration 1222/2000, Num Inliers: 106
# Iteration 1223/2000, Num Inliers: 114
# Iteration 1224/2000, Num Inliers: 100
# Iteration 1225/2000, Num Inliers: 82
# Iteration 1226/2000, Num Inliers: 55
# Iteration 1227/2000, Num Inliers: 106
# Iteration 1228/2000, Num Inliers: 71
# Iteration 1229/2000, Num Inliers: 5
# Iteration 1230/2000, Num Inliers: 58
# Iteration 1231/2000, Num Inliers: 114
# Iteration 1232/2000, Num Inliers: 38
# Iteration 1233/2000, Num Inliers: 85
# Iteration 1234/2000, Num Inliers: 114
# Iteration 1235/2000, Num Inliers: 28
# Iteration 1236/2000, Num Inliers: 67
# Iteration 1237/2000, Num Inliers: 17
# Iteration 1238/2000, Num Inliers: 72
# Iteration 1239/2000, Num Inliers: 114
# Iteration 1240/2000, Num Inliers: 5
# Iteration 1241/2000, Num Inliers: 81
# Iteration 1242/2000, Num Inliers: 84
# Iteration 1243/2000, Num Inliers: 39
# Iteration 1244/2000, Num Inliers: 29
# Iteration 1245/2000, Num Inliers: 64
# Iteration 1246/2000, Num Inliers: 65
# Iteration 1247/2000, Num Inliers: 5
# Iteration 1248/2000, Num Inliers: 41
# Iteration 1249/2000, Num Inliers: 28
# Iteration 1250/2000, Num Inliers: 5
# Iteration 1251/2000, Num Inliers: 77
# Iteration 1252/2000, Num Inliers: 42
# Iteration 1253/2000, Num Inliers: 13
# Iteration 1254/2000, Num Inliers: 113
# Iteration 1255/2000, Num Inliers: 84
# Iteration 1256/2000, Num Inliers: 11
# Iteration 1257/2000, Num Inliers: 108
# Iteration 1258/2000, Num Inliers: 34
# Iteration 1259/2000, Num Inliers: 114
# Iteration 1260/2000, Num Inliers: 113
# Iteration 1261/2000, Num Inliers: 22
# Iteration 1262/2000, Num Inliers: 15
# Iteration 1263/2000, Num Inliers: 4
# Iteration 1264/2000, Num Inliers: 114
# Iteration 1265/2000, Num Inliers: 8
# Iteration 1266/2000, Num Inliers: 33
# Iteration 1267/2000, Num Inliers: 29
# Iteration 1268/2000, Num Inliers: 5
# Iteration 1269/2000, Num Inliers: 6
# Iteration 1270/2000, Num Inliers: 7
# Iteration 1271/2000, Num Inliers: 84
# Iteration 1272/2000, Num Inliers: 38
# Iteration 1273/2000, Num Inliers: 78
# Iteration 1274/2000, Num Inliers: 95
# Iteration 1275/2000, Num Inliers: 12
# Iteration 1276/2000, Num Inliers: 4
# Iteration 1277/2000, Num Inliers: 102
# Iteration 1278/2000, Num Inliers: 114
# Iteration 1279/2000, Num Inliers: 90
# Iteration 1280/2000, Num Inliers: 101
# Iteration 1281/2000, Num Inliers: 114
# Iteration 1282/2000, Num Inliers: 114
# Iteration 1283/2000, Num Inliers: 39
# Iteration 1284/2000, Num Inliers: 77
# Iteration 1285/2000, Num Inliers: 76
# Iteration 1286/2000, Num Inliers: 17
# Iteration 1287/2000, Num Inliers: 99
# Iteration 1288/2000, Num Inliers: 23
# Iteration 1289/2000, Num Inliers: 110
# Iteration 1290/2000, Num Inliers: 86
# Iteration 1291/2000, Num Inliers: 90
# Iteration 1292/2000, Num Inliers: 57
# Iteration 1293/2000, Num Inliers: 103
# Iteration 1294/2000, Num Inliers: 114
# Iteration 1295/2000, Num Inliers: 83
# Iteration 1296/2000, Num Inliers: 108
# Iteration 1297/2000, Num Inliers: 6
# Iteration 1298/2000, Num Inliers: 4
# Iteration 1299/2000, Num Inliers: 10
# Iteration 1300/2000, Num Inliers: 7
# Iteration 1301/2000, Num Inliers: 114
# Iteration 1302/2000, Num Inliers: 4
# Iteration 1303/2000, Num Inliers: 103
# Iteration 1304/2000, Num Inliers: 114
# Iteration 1305/2000, Num Inliers: 37
# Iteration 1306/2000, Num Inliers: 7
# Iteration 1307/2000, Num Inliers: 105
# Iteration 1308/2000, Num Inliers: 25
# Iteration 1309/2000, Num Inliers: 95
# Iteration 1310/2000, Num Inliers: 20
# Iteration 1311/2000, Num Inliers: 104
# Iteration 1312/2000, Num Inliers: 113
# Iteration 1313/2000, Num Inliers: 95
# Iteration 1314/2000, Num Inliers: 95
# Iteration 1315/2000, Num Inliers: 59
# Iteration 1316/2000, Num Inliers: 8
# Iteration 1317/2000, Num Inliers: 13
# Iteration 1318/2000, Num Inliers: 114
# Iteration 1319/2000, Num Inliers: 5
# Iteration 1320/2000, Num Inliers: 114
# ...
# Iteration 1572/2000, Num Inliers: 23
# Iteration 1573/2000, Num Inliers: 17
# Iteration 1574/2000, Num Inliers: 15
# Iteration 1575/2000, Num Inliers: 56
# Iteration 1576/2000, Num Inliers: 26
# Iteration 1577/2000, Num Inliers: 45
# Iteration 1578/2000, Num Inliers: 4
# Iteration 1579/2000, Num Inliers: 22
# Iteration 1580/2000, Num Inliers: 50
# Iteration 1581/2000, Num Inliers: 45
# Iteration 1582/2000, Num Inliers: 72
# Iteration 1583/2000, Num Inliers: 37
# Iteration 1584/2000, Num Inliers: 63
# Iteration 1585/2000, Num Inliers: 70
# Iteration 1586/2000, Num Inliers: 45
# Iteration 1587/2000, Num Inliers: 70
# Iteration 1588/2000, Num Inliers: 74
# Iteration 1589/2000, Num Inliers: 74
# Iteration 1590/2000, Num Inliers: 48
# Iteration 1591/2000, Num Inliers: 14
# Iteration 1592/2000, Num Inliers: 24
# Iteration 1593/2000, Num Inliers: 67
# Iteration 1594/2000, Num Inliers: 63
# Iteration 1595/2000, Num Inliers: 34
# Iteration 1596/2000, Num Inliers: 19
# Iteration 1597/2000, Num Inliers: 71
# Iteration 1598/2000, Num Inliers: 15
# Iteration 1599/2000, Num Inliers: 74
# Iteration 1600/2000, Num Inliers: 52
# Iteration 1601/2000, Num Inliers: 63
# Iteration 1602/2000, Num Inliers: 74
# Iteration 1603/2000, Num Inliers: 74
# Iteration 1604/2000, Num Inliers: 72
# Iteration 1605/2000, Num Inliers: 21
# Iteration 1606/2000, Num Inliers: 10
# Iteration 1607/2000, Num Inliers: 8
# Iteration 1608/2000, Num Inliers: 74
# Iteration 1609/2000, Num Inliers: 47
# Iteration 1610/2000, Num Inliers: 11
# Iteration 1611/2000, Num Inliers: 48
# Iteration 1612/2000, Num Inliers: 12
# Iteration 1613/2000, Num Inliers: 63
# Iteration 1614/2000, Num Inliers: 60
# Iteration 1615/2000, Num Inliers: 41
# Iteration 1616/2000, Num Inliers: 73
# Iteration 1617/2000, Num Inliers: 20
# Iteration 1618/2000, Num Inliers: 23
# Iteration 1619/2000, Num Inliers: 56
# Iteration 1620/2000, Num Inliers: 73
# Iteration 1621/2000, Num Inliers: 62
# Iteration 1622/2000, Num Inliers: 14
# Iteration 1623/2000, Num Inliers: 11
# Iteration 1624/2000, Num Inliers: 16
# Iteration 1625/2000, Num Inliers: 26
# Iteration 1626/2000, Num Inliers: 9
# Iteration 1627/2000, Num Inliers: 18
# Iteration 1628/2000, Num Inliers: 64
# Iteration 1629/2000, Num Inliers: 67
# Iteration 1630/2000, Num Inliers: 56
# Iteration 1631/2000, Num Inliers: 49
# Iteration 1632/2000, Num Inliers: 16
# Iteration 1633/2000, Num Inliers: 72
# Iteration 1634/2000, Num Inliers: 15
# Iteration 1635/2000, Num Inliers: 5
# Iteration 1636/2000, Num Inliers: 74
# Iteration 1637/2000, Num Inliers: 59
# Iteration 1638/2000, Num Inliers: 60
# Iteration 1639/2000, Num Inliers: 70
# Iteration 1640/2000, Num Inliers: 28
# Iteration 1641/2000, Num Inliers: 74
# Iteration 1642/2000, Num Inliers: 51
# Iteration 1643/2000, Num Inliers: 74
# Iteration 1644/2000, Num Inliers: 32
# Iteration 1645/2000, Num Inliers: 41
# Iteration 1646/2000, Num Inliers: 63
# Iteration 1647/2000, Num Inliers: 53
# Iteration 1648/2000, Num Inliers: 63
# Iteration 1649/2000, Num Inliers: 13
# Iteration 1650/2000, Num Inliers: 74
# Iteration 1651/2000, Num Inliers: 62
# Iteration 1652/2000, Num Inliers: 37
# Iteration 1653/2000, Num Inliers: 24
# Iteration 1654/2000, Num Inliers: 13
# Iteration 1655/2000, Num Inliers: 0
# Iteration 1656/2000, Num Inliers: 74
# Iteration 1657/2000, Num Inliers: 8
# Iteration 1658/2000, Num Inliers: 42
# Iteration 1659/2000, Num Inliers: 74
# Iteration 1660/2000, Num Inliers: 9
# Iteration 1661/2000, Num Inliers: 19
# Iteration 1662/2000, Num Inliers: 12
# Iteration 1663/2000, Num Inliers: 20
# Iteration 1664/2000, Num Inliers: 36
# Iteration 1665/2000, Num Inliers: 17
# Iteration 1666/2000, Num Inliers: 74
# Iteration 1667/2000, Num Inliers: 22
# Iteration 1668/2000, Num Inliers: 74
# Iteration 1669/2000, Num Inliers: 74
# Iteration 1670/2000, Num Inliers: 60
# Iteration 1671/2000, Num Inliers: 74
# Iteration 1672/2000, Num Inliers: 14
# Iteration 1673/2000, Num Inliers: 7
# Iteration 1674/2000, Num Inliers: 6
# Iteration 1675/2000, Num Inliers: 59
# Iteration 1676/2000, Num Inliers: 32
# Iteration 1677/2000, Num Inliers: 18
# Iteration 1678/2000, Num Inliers: 64
# Iteration 1679/2000, Num Inliers: 73
# Iteration 1680/2000, Num Inliers: 74
# Iteration 1681/2000, Num Inliers: 74
# Iteration 1682/2000, Num Inliers: 4
# Iteration 1683/2000, Num Inliers: 11
# Iteration 1684/2000, Num Inliers: 50
# Iteration 1685/2000, Num Inliers: 64
# Iteration 1686/2000, Num Inliers: 4
# Iteration 1687/2000, Num Inliers: 71
# Iteration 1688/2000, Num Inliers: 6
# Iteration 1689/2000, Num Inliers: 74
# Iteration 1690/2000, Num Inliers: 15
# Iteration 1691/2000, Num Inliers: 0
# Iteration 1692/2000, Num Inliers: 74
# Iteration 1693/2000, Num Inliers: 36
# Iteration 1694/2000, Num Inliers: 48
# Iteration 1695/2000, Num Inliers: 9
# Iteration 1696/2000, Num Inliers: 13
# Iteration 1697/2000, Num Inliers: 9
# Iteration 1698/2000, Num Inliers: 72
# Iteration 1699/2000, Num Inliers: 70
# Iteration 1700/2000, Num Inliers: 74
# Iteration 1701/2000, Num Inliers: 8
# Iteration 1702/2000, Num Inliers: 39
# Iteration 1703/2000, Num Inliers: 74
# Iteration 1704/2000, Num Inliers: 23
# Iteration 1705/2000, Num Inliers: 74
# Iteration 1706/2000, Num Inliers: 12
# Iteration 1707/2000, Num Inliers: 10
# Iteration 1708/2000, Num Inliers: 72
# Iteration 1709/2000, Num Inliers: 36
# Iteration 1710/2000, Num Inliers: 66
# Iteration 1711/2000, Num Inliers: 38
# Iteration 1712/2000, Num Inliers: 67
# Iteration 1713/2000, Num Inliers: 4
# Iteration 1714/2000, Num Inliers: 7
# Iteration 1715/2000, Num Inliers: 74
# Iteration 1716/2000, Num Inliers: 44
# Iteration 1717/2000, Num Inliers: 22
# Iteration 1718/2000, Num Inliers: 29
# Iteration 1719/2000, Num Inliers: 54
# Iteration 1720/2000, Num Inliers: 31
# Iteration 1721/2000, Num Inliers: 24
# Iteration 1722/2000, Num Inliers: 10
# Iteration 1723/2000, Num Inliers: 73
# Iteration 1724/2000, Num Inliers: 21
# Iteration 1725/2000, Num Inliers: 73
# Iteration 1726/2000, Num Inliers: 71
# Iteration 1727/2000, Num Inliers: 56
# Iteration 1728/2000, Num Inliers: 67
# Iteration 1729/2000, Num Inliers: 10
# Iteration 1730/2000, Num Inliers: 9
# Iteration 1731/2000, Num Inliers: 5
# Iteration 1732/2000, Num Inliers: 23
# Iteration 1733/2000, Num Inliers: 64
# Iteration 1734/2000, Num Inliers: 37
# Iteration 1735/2000, Num Inliers: 37
# Iteration 1736/2000, Num Inliers: 56
# Iteration 1737/2000, Num Inliers: 68
# Iteration 1738/2000, Num Inliers: 74
# Iteration 1739/2000, Num Inliers: 26
# Iteration 1740/2000, Num Inliers: 8
# Iteration 1741/2000, Num Inliers: 45
# Iteration 1742/2000, Num Inliers: 8
# Iteration 1743/2000, Num Inliers: 74
# Iteration 1744/2000, Num Inliers: 24
# Iteration 1745/2000, Num Inliers: 31
# Iteration 1746/2000, Num Inliers: 10
# Iteration 1747/2000, Num Inliers: 53
# Iteration 1748/2000, Num Inliers: 57
# Iteration 1749/2000, Num Inliers: 32
# Iteration 1750/2000, Num Inliers: 73
# Iteration 1751/2000, Num Inliers: 65
# Iteration 1752/2000, Num Inliers: 4
# Iteration 1753/2000, Num Inliers: 39
# Iteration 1754/2000, Num Inliers: 74
# Iteration 1755/2000, Num Inliers: 5
# Iteration 1756/2000, Num Inliers: 27
# Iteration 1757/2000, Num Inliers: 74
# Iteration 1758/2000, Num Inliers: 5
# Iteration 1759/2000, Num Inliers: 22
# Iteration 1760/2000, Num Inliers: 25
# Iteration 1761/2000, Num Inliers: 72
# Iteration 1762/2000, Num Inliers: 55
# Iteration 1763/2000, Num Inliers: 14
# Iteration 1764/2000, Num Inliers: 36
# Iteration 1765/2000, Num Inliers: 67
# Iteration 1766/2000, Num Inliers: 18
# Iteration 1767/2000, Num Inliers: 17
# Iteration 1768/2000, Num Inliers: 34
# Iteration 1769/2000, Num Inliers: 7
# Iteration 1770/2000, Num Inliers: 31
# Iteration 1771/2000, Num Inliers: 59
# Iteration 1772/2000, Num Inliers: 60
# Iteration 1773/2000, Num Inliers: 37
# Iteration 1774/2000, Num Inliers: 42
# Iteration 1775/2000, Num Inliers: 33
# Iteration 1776/2000, Num Inliers: 74
# Iteration 1777/2000, Num Inliers: 25
# Iteration 1778/2000, Num Inliers: 27
# Iteration 1779/2000, Num Inliers: 39
# Iteration 1780/2000, Num Inliers: 6
# Iteration 1781/2000, Num Inliers: 45
# Iteration 1782/2000, Num Inliers: 65
# Iteration 1783/2000, Num Inliers: 15
# Iteration 1784/2000, Num Inliers: 53
# Iteration 1785/2000, Num Inliers: 61
# Iteration 1786/2000, Num Inliers: 74
# Iteration 1787/2000, Num Inliers: 26
# Iteration 1788/2000, Num Inliers: 74
# Iteration 1789/2000, Num Inliers: 4
# Iteration 1790/2000, Num Inliers: 27
# Iteration 1791/2000, Num Inliers: 6
# Iteration 1792/2000, Num Inliers: 13
# Iteration 1793/2000, Num Inliers: 67
# Iteration 1794/2000, Num Inliers: 49
# Iteration 1795/2000, Num Inliers: 29
# Iteration 1796/2000, Num Inliers: 45
# Iteration 1797/2000, Num Inliers: 74
# Iteration 1798/2000, Num Inliers: 74
# Iteration 1799/2000, Num Inliers: 53
# Iteration 1800/2000, Num Inliers: 32
# Iteration 1801/2000, Num Inliers: 37
# Iteration 1802/2000, Num Inliers: 28
# Iteration 1803/2000, Num Inliers: 27
# Iteration 1804/2000, Num Inliers: 15
# Iteration 1805/2000, Num Inliers: 35
# Iteration 1806/2000, Num Inliers: 50
# Iteration 1807/2000, Num Inliers: 27
# Iteration 1808/2000, Num Inliers: 74
# Iteration 1809/2000, Num Inliers: 19
# Iteration 1810/2000, Num Inliers: 74
# Iteration 1811/2000, Num Inliers: 58
# Iteration 1812/2000, Num Inliers: 11
# Iteration 1813/2000, Num Inliers: 69
# Iteration 1814/2000, Num Inliers: 19
# Iteration 1815/2000, Num Inliers: 32
# Iteration 1816/2000, Num Inliers: 20
# Iteration 1817/2000, Num Inliers: 74
# Iteration 1818/2000, Num Inliers: 9
# Iteration 1819/2000, Num Inliers: 5
# Iteration 1820/2000, Num Inliers: 73
# Iteration 1821/2000, Num Inliers: 47
# Iteration 1822/2000, Num Inliers: 63
# Iteration 1823/2000, Num Inliers: 74
# Iteration 1824/2000, Num Inliers: 72
# Iteration 1825/2000, Num Inliers: 74
# Iteration 1826/2000, Num Inliers: 4
# Iteration 1827/2000, Num Inliers: 56
# Iteration 1828/2000, Num Inliers: 14
# Iteration 1829/2000, Num Inliers: 5
# Iteration 1830/2000, Num Inliers: 35
# Iteration 1831/2000, Num Inliers: 47
# Iteration 1832/2000, Num Inliers: 4
# Iteration 1833/2000, Num Inliers: 46
# Iteration 1834/2000, Num Inliers: 72
# Iteration 1835/2000, Num Inliers: 47
# Iteration 1836/2000, Num Inliers: 7
# Iteration 1837/2000, Num Inliers: 68
# Iteration 1838/2000, Num Inliers: 47
# Iteration 1839/2000, Num Inliers: 72
# Iteration 1840/2000, Num Inliers: 16
# Iteration 1841/2000, Num Inliers: 4
# Iteration 1842/2000, Num Inliers: 73
# Iteration 1843/2000, Num Inliers: 55
# Iteration 1844/2000, Num Inliers: 61
# Iteration 1845/2000, Num Inliers: 38
# Iteration 1846/2000, Num Inliers: 17
# Iteration 1847/2000, Num Inliers: 41
# Iteration 1848/2000, Num Inliers: 11
# Iteration 1849/2000, Num Inliers: 8
# Iteration 1850/2000, Num Inliers: 39
# Iteration 1851/2000, Num Inliers: 23
# Iteration 1852/2000, Num Inliers: 5
# Iteration 1853/2000, Num Inliers: 53
# Iteration 1854/2000, Num Inliers: 69
# Iteration 1855/2000, Num Inliers: 12
# Iteration 1856/2000, Num Inliers: 20
# Iteration 1857/2000, Num Inliers: 5
# Iteration 1858/2000, Num Inliers: 67
# Iteration 1859/2000, Num Inliers: 62
# Iteration 1860/2000, Num Inliers: 45
# Iteration 1861/2000, Num Inliers: 5
# Iteration 1862/2000, Num Inliers: 74
# Iteration 1863/2000, Num Inliers: 74
# Iteration 1864/2000, Num Inliers: 73
# Iteration 1865/2000, Num Inliers: 9
# Iteration 1866/2000, Num Inliers: 6
# Iteration 1867/2000, Num Inliers: 5
# Iteration 1868/2000, Num Inliers: 73
# Iteration 1869/2000, Num Inliers: 29
# Iteration 1870/2000, Num Inliers: 12
# Iteration 1871/2000, Num Inliers: 24
# Iteration 1872/2000, Num Inliers: 47
# Iteration 1873/2000, Num Inliers: 7
# Iteration 1874/2000, Num Inliers: 56
# Iteration 1875/2000, Num Inliers: 54
# Iteration 1876/2000, Num Inliers: 22
# Iteration 1877/2000, Num Inliers: 15
# Iteration 1878/2000, Num Inliers: 71
# Iteration 1879/2000, Num Inliers: 18
# Iteration 1880/2000, Num Inliers: 58
# Iteration 1881/2000, Num Inliers: 8
# Iteration 1882/2000, Num Inliers: 7
# Iteration 1883/2000, Num Inliers: 67
# Iteration 1884/2000, Num Inliers: 70
# Iteration 1885/2000, Num Inliers: 22
# Iteration 1886/2000, Num Inliers: 7
# Iteration 1887/2000, Num Inliers: 60
# Iteration 1888/2000, Num Inliers: 74
# Iteration 1889/2000, Num Inliers: 63
# Iteration 1890/2000, Num Inliers: 25
# Iteration 1891/2000, Num Inliers: 74
# Iteration 1892/2000, Num Inliers: 49
# Iteration 1893/2000, Num Inliers: 21
# Iteration 1894/2000, Num Inliers: 29
# Iteration 1895/2000, Num Inliers: 39
# Iteration 1896/2000, Num Inliers: 9
# Iteration 1897/2000, Num Inliers: 22
# Iteration 1898/2000, Num Inliers: 8
# Iteration 1899/2000, Num Inliers: 8
# Iteration 1900/2000, Num Inliers: 4
# Iteration 1901/2000, Num Inliers: 74
# Iteration 1902/2000, Num Inliers: 59
# Iteration 1903/2000, Num Inliers: 74
# Iteration 1904/2000, Num Inliers: 27
# Iteration 1905/2000, Num Inliers: 71
# Iteration 1906/2000, Num Inliers: 36
# Iteration 1907/2000, Num Inliers: 6
# Iteration 1908/2000, Num Inliers: 64
# Iteration 1909/2000, Num Inliers: 9
# Iteration 1910/2000, Num Inliers: 57
# Iteration 1911/2000, Num Inliers: 58
# Iteration 1912/2000, Num Inliers: 7
# Iteration 1913/2000, Num Inliers: 48
# Iteration 1914/2000, Num Inliers: 54
# Iteration 1915/2000, Num Inliers: 73
# Iteration 1916/2000, Num Inliers: 72
# Iteration 1917/2000, Num Inliers: 37
# Iteration 1918/2000, Num Inliers: 10
# Iteration 1919/2000, Num Inliers: 9
# Iteration 1920/2000, Num Inliers: 10
# Iteration 1921/2000, Num Inliers: 5
# Iteration 1922/2000, Num Inliers: 13
# Iteration 1923/2000, Num Inliers: 74
# Iteration 1924/2000, Num Inliers: 43
# Iteration 1925/2000, Num Inliers: 68
# Iteration 1926/2000, Num Inliers: 22
# Iteration 1927/2000, Num Inliers: 0
# Iteration 1928/2000, Num Inliers: 34
# Iteration 1929/2000, Num Inliers: 19
# Iteration 1930/2000, Num Inliers: 37
# Iteration 1931/2000, Num Inliers: 42
# Iteration 1932/2000, Num Inliers: 26
# Iteration 1933/2000, Num Inliers: 18
# Iteration 1934/2000, Num Inliers: 72
# Iteration 1935/2000, Num Inliers: 4
# Iteration 1936/2000, Num Inliers: 62
# Iteration 1937/2000, Num Inliers: 63
# Iteration 1938/2000, Num Inliers: 12
# Iteration 1939/2000, Num Inliers: 5
# Iteration 1940/2000, Num Inliers: 72
# Iteration 1941/2000, Num Inliers: 25
# Iteration 1942/2000, Num Inliers: 7
# Iteration 1943/2000, Num Inliers: 7
# Iteration 1944/2000, Num Inliers: 11
# Iteration 1945/2000, Num Inliers: 63
# Iteration 1946/2000, Num Inliers: 68
# Iteration 1947/2000, Num Inliers: 52
# Iteration 1948/2000, Num Inliers: 74
# Iteration 1949/2000, Num Inliers: 72
# Iteration 1950/2000, Num Inliers: 35
# Iteration 1951/2000, Num Inliers: 6
# Iteration 1952/2000, Num Inliers: 27
# Iteration 1953/2000, Num Inliers: 13
# Iteration 1954/2000, Num Inliers: 73
# Iteration 1955/2000, Num Inliers: 9
# Iteration 1956/2000, Num Inliers: 70
# Iteration 1957/2000, Num Inliers: 72
# Iteration 1958/2000, Num Inliers: 61
# Iteration 1959/2000, Num Inliers: 47
# Iteration 1960/2000, Num Inliers: 4
# Iteration 1961/2000, Num Inliers: 37
# Iteration 1962/2000, Num Inliers: 60
# Iteration 1963/2000, Num Inliers: 17
# Iteration 1964/2000, Num Inliers: 74
# Iteration 1965/2000, Num Inliers: 74
# Iteration 1966/2000, Num Inliers: 54
# Iteration 1967/2000, Num Inliers: 62
# Iteration 1968/2000, Num Inliers: 7
# Iteration 1969/2000, Num Inliers: 19
# Iteration 1970/2000, Num Inliers: 74
# Iteration 1971/2000, Num Inliers: 7
# Iteration 1972/2000, Num Inliers: 29
# Iteration 1973/2000, Num Inliers: 70
# Iteration 1974/2000, Num Inliers: 72
# Iteration 1975/2000, Num Inliers: 74
# Iteration 1976/2000, Num Inliers: 74
# Iteration 1977/2000, Num Inliers: 52
# Iteration 1978/2000, Num Inliers: 24
# Iteration 1979/2000, Num Inliers: 72
# Iteration 1980/2000, Num Inliers: 65
# Iteration 1981/2000, Num Inliers: 11
# Iteration 1982/2000, Num Inliers: 21
# Iteration 1983/2000, Num Inliers: 20
# Iteration 1984/2000, Num Inliers: 12
# Iteration 1985/2000, Num Inliers: 17
# Iteration 1986/2000, Num Inliers: 9
# Iteration 1987/2000, Num Inliers: 17
# Iteration 1988/2000, Num Inliers: 73
# Iteration 1989/2000, Num Inliers: 70
# Iteration 1990/2000, Num Inliers: 9
# Iteration 1991/2000, Num Inliers: 9
# Iteration 1992/2000, Num Inliers: 22
# Iteration 1993/2000, Num Inliers: 15
# Iteration 1994/2000, Num Inliers: 35
# Iteration 1995/2000, Num Inliers: 72
# Iteration 1996/2000, Num Inliers: 63
# Iteration 1997/2000, Num Inliers: 5
# Iteration 1998/2000, Num Inliers: 44
# Iteration 1999/2000, Num Inliers: 25
# Iteration 2000/2000, Num Inliers: 13
# Best model found with 74 inliers.
# Image 1-3 matching time: 0.363 seconds
# Found 74 inliers out of 76 matches
# Stitching left image took: 6.55s
# Stitching right image took: 6.60s

# %% [markdown]
# ### Task: Try capture your own images and stich to panorama.
# One panorama with at least 5 images is sufficient, the current example hardcodes 3 images, can you read from all images in a directory?
#
# What else do you need to change to recover the complete panorama?
#
# hint: You might need to make your canvas larger for more images.

# %%
im1 = cv2.imread('001.jpg', cv2.IMREAD_COLOR)  # Read the center image
im2 = cv2.imread('002.jpg', cv2.IMREAD_COLOR)  # Read the left image
im3 = cv2.imread('003.jpg', cv2.IMREAD_COLOR)  # Read the right image

# Convert images
im1_gray, im1_rgb = load_and_convert_image(im1)
im2_gray, im2_rgb = load_and_convert_image(im2)
im3_gray, im3_rgb = load_and_convert_image(im3)

#### Match Features and Estimate Homographies
print("\n=== Matching Features between Images ===")

# Match im1 and im2
t0 = time.time()
kp1_2, kp2, matches1_2 = detect_and_match(im1_gray, im2_gray)
H1to2, inliers1_2 = ransac_homography_manual(kp1_2, kp2, matches1_2)
print(f"Image 1-2 matching time: {time.time()-t0:.3f} seconds")
print(f"Found {len(inliers1_2)} inliers out of {len(matches1_2)} matches")

# Match im1 and im3
t0 = time.time()
kp1_3, kp3, matches1_3 = detect_and_match(im1_gray, im3_gray)
H1to3, inliers1_3 = ransac_homography_manual(kp1_3, kp3, matches1_3)
print(f"Image 1-3 matching time: {time.time()-t0:.3f} seconds")
print(f"Found {len(inliers1_3)} inliers out of {len(matches1_3)} matches")

# Visualize matches
visualize_matches(im1_rgb, im2_rgb, kp1_2, kp2, inliers1_2, "Image 1-2 Inlier Matches")
visualize_matches(im1_rgb, im3_rgb, kp1_3, kp3, inliers1_3, "Image 1-3 Inlier Matches")



# Stitch images
result = im1.copy()
result = stitch_image(result, im2, H1to2, 'left')
result = stitch_image(result, im3, H1to3, 'right')

# Display final panorama
plt.figure(figsize=(15, 8))
plt.imshow(result)
plt.title("Final Panorama using SIFT and RANSAC")
plt.axis('off')
plt.show()
